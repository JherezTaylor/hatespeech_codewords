# %%
import logging
logging.root.handlers = []  # Jupyter messes up logging so needs a reset
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

import pandas as pd
import numpy as np
import gensim
import nltk

from sklearn import preprocessing, metrics, decomposition, pipeline, dummy
from sklearn import linear_model, svm, ensemble, multioutput

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from gensim.models import KeyedVectors
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2017-06-03 20:52:43,467 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
import sys
sys.path.append('../classifier/PatternEmotionClassifier/')
from pattern_classifier import  SimpleClassifier, PatternVectorizer

# %%
tweets = pd.read_csv('../classifier/PatternEmotionClassifier/test/annotated/annotated_tweets.tsv', sep='\t', names=['text', 'emo1', 'emo2', 'emo3'], dtype='str')
tweets.emo1.value_counts()
# Out:
# joy             456
# anticipation    272
# disgust         183
# sadness         165
# surprise        125
# anger           107
# trust           102
# fear             87
# Name: emo1, dtype: int64

# %%
train_data = pd.read_csv('../data/training/train_merged_8emo.tsv', sep='\t', names=['emotions', 'text'])
train_data.dropna(inplace=True)

# %%
test_data = pd.DataFrame()
test_data['text'] = tweets['text']
test_data['emotions'] = tweets['emo1']

# %%
tweets_emotions = [set(emos) & set(train_data.emotions) for emos in tweets[['emo1', 'emo2', 'emo3']].values]
mlb = preprocessing.MultiLabelBinarizer()
y_bin_emotions = mlb.fit_transform(tweets_emotions)

# %%
def evaluate_prediction(predictions, target):
    print(metrics.classification_report(target, predictions))
    print('Accuracy:')
    print(metrics.accuracy_score(target, predictions))

# %%
def evaluate_prob(prediction, target, binarizer):
    predict_class = binarizer.classes_[prediction.argmax(axis=1)]
    target_class = binarizer.classes_[target.argmax(axis=1)]
    evaluate_prediction(predict_class, target_class)
    
    print('average_precision_score: %f' % metrics.average_precision_score(target, prediction))
    print('label_ranking_average_precision_score: %f' % metrics.label_ranking_average_precision_score(target, prediction))
    print('label_ranking_loss: %f' % metrics.label_ranking_loss(target, prediction))

# %%
def predict(train, test, pipeline):
    pipeline.fit(train['text'], train['emotions'])
    predictions = pipeline.predict(test['text'])
    target = test['emotions']
    evaluate_prediction(predictions, target)

# %%
def softmax(z):
    assert len(z.shape) == 2
    s = np.max(z, axis=1)
    s = s[:, np.newaxis] # necessary step to do broadcasting
    e_x = np.exp(z - s)
    div = np.sum(e_x, axis=1)
    div = div[:, np.newaxis] # dito
    return e_x / div

# %% [markdown]
# ## Dummy

# %%
dummy_vectoriser = TfidfVectorizer(max_features=5)
dummy_vectoriser.fit(train_data.text)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=5, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
dummy_pipe = pipeline.Pipeline([
    ('vect', TfidfVectorizer(
        max_features=5000)),
    ('cls', dummy.DummyClassifier())
])
predict(train_data, test_data, dummy_pipe)
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.07      0.15      0.09       107
# anticipation       0.11      0.04      0.06       272
#      disgust       0.14      0.02      0.03       183
#         fear       0.05      0.14      0.07        87
#          joy       0.29      0.19      0.23       456
#      sadness       0.12      0.20      0.15       165
#     surprise       0.05      0.05      0.05       125
#        trust       0.05      0.09      0.07       102
#
#  avg / total       0.15      0.12      0.12      1497
#
# Accuracy:
# 0.118904475618

# %%
dummy_reg = dummy.DummyRegressor()
dummy_reg.fit(dummy_vectoriser.transform(train_data.text), mlb.transform(train_data.emotions.apply(lambda emo: set([emo])).values))
dummy_prob = dummy_reg.predict(dummy_vectoriser.transform(test_data.text))

# %%
evaluate_prob(dummy_prob, y_bin_emotions, mlb)
# Out:
# /home/renaud/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00       251
# anticipation       0.00      0.00      0.00       552
#      disgust       0.00      0.00      0.00       149
#         fear       0.00      0.00      0.00        56
#          joy       0.00      0.00      0.00       351
#      sadness       0.04      1.00      0.08        62
#     surprise       0.00      0.00      0.00        66
#        trust       0.00      0.00      0.00        10
#
#  avg / total       0.00      0.04      0.00      1497
#
# Accuracy:
# 0.0414161656647
# average_precision_score: 0.614980
# label_ranking_average_precision_score: 0.427554
# label_ranking_loss: 0.487380

# %% [markdown]
# ## Python pattern baseline

# %%
pv, cls = SimpleClassifier.load_from_folder('../classifier/PatternEmotionClassifier/test/patterns/8_emos/')

# %%
pattern_vect = pv.transform_parrallel(test_data.text.values, n_jobs=-1, n_chunk=500)

# %%
pattern_es_prob = cls.get_emotion_prob(pattern_vect)

# %%
cls_to_mlb = [np.where(np.array(cls.classes) == emo)[0][0] for emo in mlb.classes_.tolist()]

# %%
pattern_es_mlb = pattern_es_prob[:,cls_to_mlb]

# %%
evaluate_prob(pattern_es_mlb, y_bin_emotions, mlb)
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.40      0.20      0.27       251
# anticipation       0.52      0.38      0.44       552
#      disgust       0.14      0.06      0.08       149
#         fear       0.11      0.34      0.17        56
#          joy       0.27      0.14      0.19       351
#      sadness       0.16      0.15      0.15        62
#     surprise       0.07      0.39      0.11        66
#        trust       0.00      0.00      0.00        10
#
#  avg / total       0.35      0.25      0.28      1497
#
# Accuracy:
# 0.247828991316
# average_precision_score: 0.322029
# label_ranking_average_precision_score: 0.529072
# label_ranking_loss: 0.389337

# %% [markdown]
# ## Doc2vec Model
#
# [https://github.com/RaRe-Technologies/movie-plots-by-genre/blob/master/Document%20classification%20with%20word%20embeddings%20tutorial.ipynb](https://github.com/RaRe-Technologies/movie-plots-by-genre/blob/master/Document%20classification%20with%20word%20embeddings%20tutorial.ipynb)

# %%
#removing retweet and tweet countaining url
retweet_bool = train_data.text.str.contains('RT |rt ')
http_bool = train_data.text.str.contains('http://') 
https_bool = train_data.text.str.contains('https://')
train_data = train_data[~(retweet_bool | http_bool | https_bool)]

# %%
#remove hastag and usermention
train_data.text = train_data.text.str.replace(r"#(\w+)", '<H>')\
    .str.replace(r"@(\w+)", '<M>')\
    .str.replace('"', '')\
    .str.replace("'", '')
train_data = train_data[train_data.text != '']

# %%
train_data.dropna(inplace=True)

# %%
train_data.drop_duplicates(inplace=True)

# %%
train_data
# Out:
#          emotions                                               text
# 1             joy   More than ready for Spring and Summer !! <H> <H>
# 2           trust  we wont work if you get jealous easily <H> <H>...
# 3           trust  But appreciate what your man does for you <H> ...
# 5            fear  One of my snow globes that hasnt been played i...
# 6            fear  <M> i know, tell me about it :p and then there...
# 7             joy  Volunteering with the children this week, and ...
# 8         sadness          Couldnt go to the batting cages today <H>
# 9            fear  starting the walking dead on netflix with <M> ...
# 10           fear  definitely need to prepare my speech earlier n...
# 11        sadness                    got that shitty feeling <H> <H>
# 12          anger  im not one for coming on here and moaning, but...
# 13            joy      ? that guy is goin to bed a happy camper! <H>
# 14            joy  holy poop. this year, ezori and i will celebra...
# 15        sadness  you don’t want me, you don’t need me, like i w...
# 17        sadness           i miss crazy nights with <M> and <M> <H>
# 19        sadness  it takes me a second to figure out right from ...
# 20           fear                         <M>  just watched that <H>
# 21       surprise  wow...the power of prayer...thanks to whoever ...
# 22           fear                     London interview today <H> <H>
# 23            joy                 boom im now a red head <H> <H> <H>
# 25            joy                                        I love <H>
# 26           fear  become love will mean some falling, and shes a...
# 31           fear  <H> reviews sound great! im very excited the s...
# 32        sadness  i think i saw a person dying or died today on ...
# 33          anger                   <M> eww, wtf. thats horrible <H>
# 34            joy                found 20 dollars in my book bag <H>
# 35          trust  In car right now listenin to <H> <H> :) GREAT!...
# 36           fear  <H> this says that scientists are linking the ...
# 37            joy  Excited to book Malia with the ladies this wee...
# 38          trust                               <M> Come On Boys <H>
# ...           ...                                                ...
# 2396381       joy               Watching greys anatomy episode 1 <H>
# 2396383      fear  eadie just came down the stairs sleep walking ...
# 2396384     anger  why dont you write the same tweet a few more t...
# 2396385  surprise  That phone call I just had &lt;&lt;&lt;&lt;&lt...
# 2396386     anger  cant wait to fucking finish with this phone im...
# 2396387   sadness   dont want one tree hill to be over:( <H> <H> <H>
# 2396388     anger  The fact that Im in school and I feel like Im ...
# 2396389  surprise  <M> just jd in her p over <M> performance im p...
# 2396392       joy  So we are on exam leave for the next 3 days we...
# 2396394       joy                               <H> <H> Hump Day!!!!
# 2396395      fear              hate getting my bloods done💉😥 <H> <H>
# 2396396   sadness  <M> have u died or what? Thanks for replying t...
# 2396397     trust                Letting it all go felt so good. <H>
# 2396399      fear  My red headed roommates gf just walked in and ...
# 2396400     anger  typical that my internet would crash as soon a...
# 2396401       joy                          Chance is the sweetest! 
# 2396404   sadness              the things bitches do 4 attention <H>
# 2396406     trust  <M> <M> ILL NEVER GIVE UP ON GETTING A FOLLOW ...
# 2396407       joy  Someone say training in an hour? Feels like Ch...
# 2396408   sadness  wow okay this new hair makes me look like a dr...
# 2396409   sadness  Lost my playstation and wii remote :( tis  a s...
# 2396410   sadness  «<M> «<M> I Hate When Females Think U Talking ...
# 2396411       joy  got my dress for my cousins wedding today! :d ...
# 2396413      fear  i realized that my father is totally like me. <H>
# 2396414     anger  <M> haha i hear you mari mines been like that ...
# 2396415      fear  When youve got a funny feeling that something ...
# 2396417       joy  going to bed with a giant smile on my face <H>...
# 2396418     anger  <M> its private for god sake now they are ques...
# 2396419      fear  <M> Yeah thats great! Better reset it! <H>! wh...
# 2396420  surprise  milans mens fashionweek &gt;&gt; devotion by d...
#
# [1801966 rows x 2 columns]

# %%
train_data.count()
# Out:
# emotions    1801966
# text        1801966
# dtype: int64

# %%
train_data.emotions.value_counts()
# Out:
# sadness     426413
# fear        341707
# joy         339877
# anger       329212
# trust       205040
# surprise    159717
# Name: emotions, dtype: int64

# %%
lower_preprocessor = lambda text: text.lower()

# %%
tweet_tokenizer = TweetTokenizer()

# %% [markdown]
# ## Baseline: bag of words, n-grams, tf-idf
# Let's start with some simple baselines before diving into more advanced methods.

# %% [markdown]
# ### Bag of words
# The simplest document feature is just a count of each word occurrence in a document.
# We remove stop-words and use NLTK tokenizer then limit our vocabulary to 3k most frequent words.

# %%
# %%time
# training

bow_pipe = pipeline.Pipeline([
    ('vect', CountVectorizer(
        analyzer="word", 
        tokenizer=tweet_tokenizer.tokenize,
        preprocessor=lower_preprocessor, 
        max_features=100000)),
    ('cls', linear_model.SGDClassifier(n_iter=100, loss='epsilon_insensitive'))
])

predict(train_data, test_data, bow_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.29      0.42      0.35       107
#        fear       0.17      0.41      0.24        87
#         joy       0.76      0.42      0.54       456
#     sadness       0.39      0.47      0.43       165
#    surprise       0.19      0.04      0.07       125
#       trust       0.28      0.54      0.37       102
#
# avg / total       0.49      0.39      0.40      1042
#
# Accuracy:
# 0.39443378119
# CPU times: user 10min 34s, sys: 2.96 s, total: 10min 37s
# Wall time: 10min 36s

# %% [markdown]
# Multi-modal logistic regression is a simple white-box classifier. We will use either logistic regression or KNN throughout this tutorial.

# %% [markdown]
# ### Character N-grams
#
# A character n-gram is a chunk of a document of length n. It is a poor man's tokenizer but sometimes works well. The parameter n depends on language and the corpus. We choose length between 3 and 6 characters and to only focus on 3k most popular ones.

# %%
# %%time

ngram_pipe = pipeline.Pipeline([
    ('vect', CountVectorizer(
        analyzer="char",
        ngram_range=([2,5]),
        tokenizer=None,    
        preprocessor=lower_preprocessor,
        max_features=50000
    )),
    ('cls', linear_model.SGDClassifier(n_iter=20))
])

predict(train_data, test_data, ngram_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.52      0.11      0.18       107
#        fear       0.15      0.52      0.23        87
#         joy       0.73      0.45      0.56       456
#     sadness       0.39      0.46      0.42       165
#    surprise       0.18      0.13      0.15       125
#       trust       0.31      0.44      0.36       102
#
# avg / total       0.50      0.38      0.40      1042
#
# Accuracy:
# 0.384836852207
# CPU times: user 12min 51s, sys: 1min 35s, total: 14min 26s
# Wall time: 53min 40s

# %% [markdown]
# ### TF-IDF
#
# Term Frequency - Inverse Document Frequency is a little more advanced way to count words in a document. It adjusts for document length, word frequency and most importantly for frequency of a particular word in a particular document.

# %%
# %%time

tfidf_pipe = pipeline.Pipeline([
    ('vect', TfidfVectorizer(
        min_df=10, 
        max_df=0.3,
        tokenizer=tweet_tokenizer.tokenize,
        ngram_range=(1,3),
        preprocessor=lower_preprocessor)),
    ('cls', linear_model.SGDClassifier(n_iter=20, loss='epsilon_insensitive'))
])

predict(train_data, test_data, tfidf_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.30      0.47      0.36       107
#        fear       0.13      0.43      0.20        87
#         joy       0.73      0.46      0.57       456
#     sadness       0.47      0.45      0.46       165
#    surprise       0.15      0.02      0.04       125
#       trust       0.38      0.43      0.41       102
#
# avg / total       0.49      0.40      0.42      1042
#
# Accuracy:
# 0.404030710173
# CPU times: user 7min 41s, sys: 5.01 s, total: 7min 46s
# Wall time: 8min 5s

# %%
# %%time

tfidf_pipe = pipeline.Pipeline([
    ('vect', TfidfVectorizer(
        min_df=10,
        max_df=0.3,
        tokenizer=tweet_tokenizer.tokenize,
        preprocessor=lower_preprocessor)),
    ('cls', linear_model.SGDClassifier(n_iter=20, loss='epsilon_insensitive'))
])

predict(train_data, test_data, tfidf_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.31      0.37      0.34       107
#        fear       0.14      0.41      0.21        87
#         joy       0.77      0.45      0.57       456
#     sadness       0.43      0.50      0.46       165
#    surprise       0.16      0.03      0.05       125
#       trust       0.31      0.53      0.39       102
#
# avg / total       0.50      0.40      0.42      1042
#
# Accuracy:
# 0.404030710173
# CPU times: user 4min 17s, sys: 5.55 s, total: 4min 22s
# Wall time: 5min 44s

# %%
# %%time

ngram_tfidf_pipe = pipeline.Pipeline([
    ('vect', TfidfVectorizer(
        min_df=10,
        analyzer="char_wb",
        ngram_range=(2,5),
        tokenizer=tweet_tokenizer.tokenize,    
        preprocessor=lower_preprocessor,
        max_features=50000
    )),
    ('cls', linear_model.SGDClassifier(n_iter=20, loss='epsilon_insensitive'))
])

predict(train_data, test_data, ngram_tfidf_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.32      0.44      0.37       107
#        fear       0.13      0.41      0.19        87
#         joy       0.74      0.41      0.52       456
#     sadness       0.41      0.42      0.41       165
#    surprise       0.19      0.04      0.07       125
#       trust       0.28      0.44      0.34       102
#
# avg / total       0.48      0.37      0.39      1042
#
# Accuracy:
# 0.37236084453
# CPU times: user 11min 23s, sys: 42.5 s, total: 12min 5s
# Wall time: 37min 54s

# %%
# %%time

ngram_tfidf_pipe = pipeline.Pipeline([
    ('vect', TfidfVectorizer(
        min_df=10,
        analyzer="char",
        ngram_range=(2,5),
        preprocessor=lower_preprocessor,
        max_features=50000
    )),
    ('cls', linear_model.SGDClassifier(n_iter=20, loss='epsilon_insensitive'))
])

predict(train_data, test_data, ngram_tfidf_pipe, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.38      0.44      0.41       107
#        fear       0.13      0.47      0.20        87
#         joy       0.76      0.41      0.53       456
#     sadness       0.40      0.39      0.40       165
#    surprise       0.19      0.04      0.07       125
#       trust       0.29      0.48      0.36       102
#
# avg / total       0.49      0.38      0.40      1042
#
# Accuracy:
# 0.376199616123
# CPU times: user 13min 28s, sys: 1min 40s, total: 15min 9s
# Wall time: 1h 4min 35s

# %% [markdown]
# ## Averaging word vectors
# Now let's use more complex features rather than just counting words.
# A great recent achievement of NLP is the word2vec embedding. See Chris Moody's video for a great introduction to word2vec.
# First we load a word2vec model. It has been pre-trained by Google on a 100 billon word Google News corpus. You can play with this model using a fun web-app.
# Link to the web-app: http://rare-technologies.com/word2vec-tutorial/#app
# Vocabulary size: 3 mln words.
# Warning: 3 mins to load, takes 4 GB of RAM.

# %%
# %%time 
wv = KeyedVectors.load_word2vec_format(
    "/home/renaud/Documents/GoogleNews-vectors-negative300.bin.gz",
    binary=True)
wv.init_sims(replace=True)
# Out:
# 2017-05-28 11:35:19,429 : INFO : loading projection weights from /home/renaud/Documents/GoogleNews-vectors-negative300.bin.gz
# 2017-05-28 12:07:25,109 : INFO : loaded (3000000, 300) matrix from /home/renaud/Documents/GoogleNews-vectors-negative300.bin.gz
# 2017-05-28 12:07:25,462 : INFO : precomputing L2-norms of word weight vectors
# CPU times: user 4min 47s, sys: 40.4 s, total: 5min 27s
# Wall time: 36min 29s

# %%
wv.vector_size
# Out:
# 300

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.syn0norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        return np.zeros(wv.vector_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, review) for review in text_list ])

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens

# %%
test_tokenized = test_data.apply(lambda r: w2v_tokenize_text(r['text']), axis=1).values
train_tokenized = train_data[:500000].apply(lambda r: w2v_tokenize_text(r['text']), axis=1).values

# %%
len(train_tokenized)
# Out:
# 500000

# %%
# %%time
X_train_word_average = word_averaging_list(wv,train_tokenized)
X_test_word_average = word_averaging_list(wv,test_tokenized)
# Out:
# CPU times: user 50.5 s, sys: 6.94 s, total: 57.5 s
# Wall time: 3min 54s

# %%
X_train_word_average = X_train_word_average[(X_train_word_average != 0).any(axis=1)]
y_train = train_data[:500000].emotions[(X_train_word_average != 0).any(axis=1)]

# %%
# %%time
w2v_avg_sgd = linear_model.SGDClassifier(n_iter=20, loss='epsilon_insensitive')
w2v_avg_sgd.fit(X_train_word_average, y_train)
# Out:
# CPU times: user 1min 4s, sys: 256 ms, total: 1min 4s
# Wall time: 1min 7s

# %%
# %%time
predicted = w2v_avg_sgd.predict(X_test_word_average)
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 360 ms

# %%
evaluate_prediction(predicted, test_data.emotions, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.19      0.21      0.20       107
#        fear       0.07      0.32      0.12        87
#         joy       0.47      0.53      0.49       456
#     sadness       0.00      0.00      0.00       165
#    surprise       0.00      0.00      0.00       125
#       trust       0.00      0.00      0.00       102
#
# avg / total       0.23      0.28      0.25      1042
#
# Accuracy:
# 0.280230326296
# /home/renaud/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Doc2Vec
# A paper by Google suggests a model for document classification called Paragraph Vectors Doc2Vec or Doc2vec in short. It is very similar to word2vec.
# It introduces 'a tag' - a word that is in every context in the document.
# For our first try we tag every plot with its genre. This makes it 'semi-supervised' learning - the genre labels is just one objective among many.

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
train_tagged = train_data.apply(
    lambda r: TaggedDocument(words=tweet_tokenizer.tokenize(r['text']), tags=[r.emotions]), axis=1)

# %%
test_tagged = test_data.apply(
    lambda r: TaggedDocument(words=tweet_tokenizer.tokenize(r['text']), tags=[r.emotions]), axis=1)

# %%
test_tagged.values[50]
# Out:
# TaggedDocument(words=['cant', 'believe', 'the', 'champions', 'league', 'is', 'back', 'next', 'week', 'and', 'the', 'pool', 'are', 'back', 'in', 'it', '😍', '😍', '😍'], tags=['joy'])

# %%
# %%time
trainsent = train_tagged.values
testsent = test_tagged.values

# simple gensim doc2vec api
doc2vec_model = Doc2Vec(trainsent, workers=1, size=5, iter=20, dm=1)

train_targets, train_regressors = zip(
    *[(doc.tags[0], doc2vec_model.infer_vector(doc.words, steps=20)) for doc in trainsent])
# Out:
# 2017-05-28 13:11:49,290 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-05-28 13:11:49,552 : INFO : collecting all words and their counts
# 2017-05-28 13:11:49,553 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-05-28 13:11:51,562 : INFO : PROGRESS: at example #10000, processed 150311 words (75982/s), 12909 word types, 6 tags
# 2017-05-28 13:11:51,885 : INFO : PROGRESS: at example #20000, processed 301643 words (492005/s), 19437 word types, 6 tags
# 2017-05-28 13:11:55,296 : INFO : PROGRESS: at example #30000, processed 453521 words (44539/s), 24654 word types, 6 tags
# 2017-05-28 13:11:55,447 : INFO : PROGRESS: at example #40000, processed 604627 words (1268511/s), 29071 word types, 6 tags
# 2017-05-28 13:11:55,598 : INFO : PROGRESS: at example #50000, processed 756586 words (1346237/s), 33072 word types, 6 tags
# 2017-05-28 13:11:55,716 : INFO : PROGRESS: at example #60000, processed 908064 words (1338281/s), 36634 word types, 6 tags
# 2017-05-28 13:11:55,847 : INFO : PROGRESS: at example #70000, processed 1058425 words (1294171/s), 39994 word types, 6 tags
# 2017-05-28 13:11:55,975 : INFO : PROGRESS: at example #80000, processed 1209457 words (1324258/s), 43214 word types, 6 tags
# 2017-05-28 13:11:56,897 : INFO : PROGRESS: at example #90000, processed 1361460 words (166219/s), 46209 word types, 6 tags
# 2017-05-28 13:11:57,017 : INFO : PROGRESS: at example #100000, processed 1512836 words (1282195/s), 49132 word types, 6 tags
# 2017-05-28 13:11:57,129 : INFO : PROGRESS: at example #110000, processed 1662622 words (1354273/s), 51967 word types, 6 tags
# 2017-05-28 13:11:57,248 : INFO : PROGRESS: at example #120000, processed 1812736 words (1346758/s), 54645 word types, 6 tags
# 2017-05-28 13:11:57,363 : INFO : PROGRESS: at example #130000, processed 1963194 words (1337129/s), 57151 word types, 6 tags
# 2017-05-28 13:11:57,480 : INFO : PROGRESS: at example #140000, processed 2113879 words (1300183/s), 59672 word types, 6 tags
# 2017-05-28 13:11:57,623 : INFO : PROGRESS: at example #150000, processed 2264283 words (1060766/s), 61957 word types, 6 tags
# 2017-05-28 13:11:57,737 : INFO : PROGRESS: at example #160000, processed 2415399 words (1341207/s), 64283 word types, 6 tags
# 2017-05-28 13:11:57,866 : INFO : PROGRESS: at example #170000, processed 2566360 words (1313952/s), 66584 word types, 6 tags
# 2017-05-28 13:11:57,980 : INFO : PROGRESS: at example #180000, processed 2716528 words (1325950/s), 68845 word types, 6 tags
# 2017-05-28 13:11:58,093 : INFO : PROGRESS: at example #190000, processed 2868419 words (1362273/s), 70925 word types, 6 tags
# 2017-05-28 13:11:58,206 : INFO : PROGRESS: at example #200000, processed 3018785 words (1340540/s), 72960 word types, 6 tags
# 2017-05-28 13:11:58,340 : INFO : PROGRESS: at example #210000, processed 3169726 words (1345856/s), 74970 word types, 6 tags
# 2017-05-28 13:11:58,465 : INFO : PROGRESS: at example #220000, processed 3320377 words (1330980/s), 77003 word types, 6 tags
# 2017-05-28 13:11:58,581 : INFO : PROGRESS: at example #230000, processed 3472559 words (1325828/s), 79045 word types, 6 tags
# 2017-05-28 13:11:58,695 : INFO : PROGRESS: at example #240000, processed 3623291 words (1333487/s), 81060 word types, 6 tags
# 2017-05-28 13:11:58,814 : INFO : PROGRESS: at example #250000, processed 3773459 words (1330196/s), 82993 word types, 6 tags
# 2017-05-28 13:11:58,937 : INFO : PROGRESS: at example #260000, processed 3924964 words (1325404/s), 84981 word types, 6 tags
# 2017-05-28 13:11:59,051 : INFO : PROGRESS: at example #270000, processed 4075969 words (1329792/s), 86744 word types, 6 tags
# 2017-05-28 13:11:59,174 : INFO : PROGRESS: at example #280000, processed 4226548 words (1308377/s), 88506 word types, 6 tags
# 2017-05-28 13:11:59,289 : INFO : PROGRESS: at example #290000, processed 4378247 words (1328778/s), 90328 word types, 6 tags
# 2017-05-28 13:11:59,413 : INFO : PROGRESS: at example #300000, processed 4529818 words (1233415/s), 92049 word types, 6 tags
# 2017-05-28 13:11:59,539 : INFO : PROGRESS: at example #310000, processed 4679243 words (1196154/s), 93798 word types, 6 tags
# 2017-05-28 13:11:59,661 : INFO : PROGRESS: at example #320000, processed 4832127 words (1277413/s), 95507 word types, 6 tags
# 2017-05-28 13:11:59,775 : INFO : PROGRESS: at example #330000, processed 4984182 words (1345397/s), 97147 word types, 6 tags
# 2017-05-28 13:11:59,897 : INFO : PROGRESS: at example #340000, processed 5134943 words (1251188/s), 98723 word types, 6 tags
# 2017-05-28 13:12:00,021 : INFO : PROGRESS: at example #350000, processed 5286552 words (1236195/s), 100362 word types, 6 tags
# 2017-05-28 13:12:00,139 : INFO : PROGRESS: at example #360000, processed 5438670 words (1293688/s), 102034 word types, 6 tags
# 2017-05-28 13:12:00,265 : INFO : PROGRESS: at example #370000, processed 5590250 words (1217633/s), 103626 word types, 6 tags
# 2017-05-28 13:12:00,380 : INFO : PROGRESS: at example #380000, processed 5741729 words (1330560/s), 105259 word types, 6 tags
# 2017-05-28 13:12:00,499 : INFO : PROGRESS: at example #390000, processed 5892355 words (1270494/s), 106826 word types, 6 tags
# 2017-05-28 13:12:00,615 : INFO : PROGRESS: at example #400000, processed 6044652 words (1326451/s), 108394 word types, 6 tags
# 2017-05-28 13:12:00,758 : INFO : PROGRESS: at example #410000, processed 6194730 words (1336575/s), 109933 word types, 6 tags
# 2017-05-28 13:12:00,879 : INFO : PROGRESS: at example #420000, processed 6346564 words (1320890/s), 111464 word types, 6 tags
# 2017-05-28 13:12:00,993 : INFO : PROGRESS: at example #430000, processed 6497540 words (1334044/s), 112927 word types, 6 tags
# 2017-05-28 13:12:01,111 : INFO : PROGRESS: at example #440000, processed 6649551 words (1295537/s), 114372 word types, 6 tags
# 2017-05-28 13:12:01,226 : INFO : PROGRESS: at example #450000, processed 6801134 words (1339927/s), 115784 word types, 6 tags
# 2017-05-28 13:12:01,341 : INFO : PROGRESS: at example #460000, processed 6952291 words (1320340/s), 117147 word types, 6 tags
# 2017-05-28 13:12:01,458 : INFO : PROGRESS: at example #470000, processed 7103214 words (1307814/s), 118507 word types, 6 tags
# 2017-05-28 13:12:01,572 : INFO : PROGRESS: at example #480000, processed 7253696 words (1335911/s), 119913 word types, 6 tags
# 2017-05-28 13:12:01,686 : INFO : PROGRESS: at example #490000, processed 7405407 words (1346560/s), 121330 word types, 6 tags
# 2017-05-28 13:12:01,801 : INFO : PROGRESS: at example #500000, processed 7557058 words (1338138/s), 122735 word types, 6 tags
# 2017-05-28 13:12:01,926 : INFO : PROGRESS: at example #510000, processed 7709446 words (1242228/s), 124115 word types, 6 tags
# 2017-05-28 13:12:02,042 : INFO : PROGRESS: at example #520000, processed 7859607 words (1315720/s), 125433 word types, 6 tags
# 2017-05-28 13:12:02,174 : INFO : PROGRESS: at example #530000, processed 8011154 words (1157224/s), 126776 word types, 6 tags
# 2017-05-28 13:12:02,309 : INFO : PROGRESS: at example #540000, processed 8162290 words (1328374/s), 128126 word types, 6 tags
# 2017-05-28 13:12:02,423 : INFO : PROGRESS: at example #550000, processed 8314925 words (1351634/s), 129436 word types, 6 tags
# 2017-05-28 13:12:02,537 : INFO : PROGRESS: at example #560000, processed 8466244 words (1335491/s), 130751 word types, 6 tags
# 2017-05-28 13:12:02,663 : INFO : PROGRESS: at example #570000, processed 8618146 words (1342792/s), 132067 word types, 6 tags
# 2017-05-28 13:12:02,781 : INFO : PROGRESS: at example #580000, processed 8769857 words (1353126/s), 133347 word types, 6 tags
# 2017-05-28 13:12:02,905 : INFO : PROGRESS: at example #590000, processed 8921180 words (1347155/s), 134669 word types, 6 tags
# 2017-05-28 13:12:03,021 : INFO : PROGRESS: at example #600000, processed 9074389 words (1334337/s), 135943 word types, 6 tags
# 2017-05-28 13:12:03,136 : INFO : PROGRESS: at example #610000, processed 9226123 words (1331316/s), 137221 word types, 6 tags
# 2017-05-28 13:12:03,259 : INFO : PROGRESS: at example #620000, processed 9378370 words (1246093/s), 138526 word types, 6 tags
# 2017-05-28 13:12:03,384 : INFO : PROGRESS: at example #630000, processed 9529551 words (1232832/s), 139733 word types, 6 tags
# 2017-05-28 13:12:03,501 : INFO : PROGRESS: at example #640000, processed 9680754 words (1301545/s), 141029 word types, 6 tags
# 2017-05-28 13:12:03,617 : INFO : PROGRESS: at example #650000, processed 9832841 words (1338511/s), 142280 word types, 6 tags
# 2017-05-28 13:12:03,734 : INFO : PROGRESS: at example #660000, processed 9984073 words (1309638/s), 143461 word types, 6 tags
# 2017-05-28 13:12:03,853 : INFO : PROGRESS: at example #670000, processed 10136595 words (1302387/s), 144713 word types, 6 tags
# 2017-05-28 13:12:03,971 : INFO : PROGRESS: at example #680000, processed 10288754 words (1320056/s), 145996 word types, 6 tags
# 2017-05-28 13:12:04,084 : INFO : PROGRESS: at example #690000, processed 10440447 words (1352308/s), 147147 word types, 6 tags
# 2017-05-28 13:12:04,197 : INFO : PROGRESS: at example #700000, processed 10593037 words (1359614/s), 148345 word types, 6 tags
# 2017-05-28 13:12:04,318 : INFO : PROGRESS: at example #710000, processed 10745917 words (1362614/s), 149562 word types, 6 tags
# 2017-05-28 13:12:04,435 : INFO : PROGRESS: at example #720000, processed 10897385 words (1311744/s), 150716 word types, 6 tags
# 2017-05-28 13:12:04,550 : INFO : PROGRESS: at example #730000, processed 11048778 words (1328190/s), 151932 word types, 6 tags
# 2017-05-28 13:12:04,667 : INFO : PROGRESS: at example #740000, processed 11199926 words (1323359/s), 153119 word types, 6 tags
# 2017-05-28 13:12:04,782 : INFO : PROGRESS: at example #750000, processed 11351736 words (1341344/s), 154270 word types, 6 tags
# 2017-05-28 13:12:04,897 : INFO : PROGRESS: at example #760000, processed 11502395 words (1317696/s), 155392 word types, 6 tags
# 2017-05-28 13:12:05,011 : INFO : PROGRESS: at example #770000, processed 11654365 words (1352153/s), 156616 word types, 6 tags
# 2017-05-28 13:12:05,125 : INFO : PROGRESS: at example #780000, processed 11805761 words (1337233/s), 157742 word types, 6 tags
# 2017-05-28 13:12:05,258 : INFO : PROGRESS: at example #790000, processed 11958785 words (1168340/s), 158849 word types, 6 tags
# 2017-05-28 13:12:05,373 : INFO : PROGRESS: at example #800000, processed 12110656 words (1332308/s), 159948 word types, 6 tags
# 2017-05-28 13:12:05,487 : INFO : PROGRESS: at example #810000, processed 12261476 words (1335944/s), 161030 word types, 6 tags
# 2017-05-28 13:12:05,604 : INFO : PROGRESS: at example #820000, processed 12413321 words (1302433/s), 162085 word types, 6 tags
# 2017-05-28 13:12:05,719 : INFO : PROGRESS: at example #830000, processed 12565081 words (1334111/s), 163237 word types, 6 tags
# 2017-05-28 13:12:05,836 : INFO : PROGRESS: at example #840000, processed 12716910 words (1306811/s), 164326 word types, 6 tags
# 2017-05-28 13:12:05,953 : INFO : PROGRESS: at example #850000, processed 12867708 words (1320053/s), 165415 word types, 6 tags
# 2017-05-28 13:12:06,066 : INFO : PROGRESS: at example #860000, processed 13018485 words (1339913/s), 166538 word types, 6 tags
# 2017-05-28 13:12:06,181 : INFO : PROGRESS: at example #870000, processed 13170694 words (1345804/s), 167637 word types, 6 tags
# 2017-05-28 13:12:06,295 : INFO : PROGRESS: at example #880000, processed 13323274 words (1347275/s), 168719 word types, 6 tags
# 2017-05-28 13:12:06,412 : INFO : PROGRESS: at example #890000, processed 13475874 words (1319459/s), 169845 word types, 6 tags
# 2017-05-28 13:12:06,530 : INFO : PROGRESS: at example #900000, processed 13627742 words (1296742/s), 170944 word types, 6 tags
# 2017-05-28 13:12:06,705 : INFO : PROGRESS: at example #910000, processed 13779198 words (869763/s), 171959 word types, 6 tags
# 2017-05-28 13:12:06,912 : INFO : PROGRESS: at example #920000, processed 13930974 words (738508/s), 173046 word types, 6 tags
# 2017-05-28 13:12:07,108 : INFO : PROGRESS: at example #930000, processed 14084310 words (783297/s), 174096 word types, 6 tags
# 2017-05-28 13:12:07,317 : INFO : PROGRESS: at example #940000, processed 14235116 words (729320/s), 175096 word types, 6 tags
# 2017-05-28 13:12:07,510 : INFO : PROGRESS: at example #950000, processed 14387354 words (793098/s), 176122 word types, 6 tags
# 2017-05-28 13:12:07,698 : INFO : PROGRESS: at example #960000, processed 14539152 words (815927/s), 177088 word types, 6 tags
# 2017-05-28 13:12:07,833 : INFO : PROGRESS: at example #970000, processed 14689594 words (1124446/s), 178072 word types, 6 tags
# 2017-05-28 13:12:07,953 : INFO : PROGRESS: at example #980000, processed 14841494 words (1285052/s), 179051 word types, 6 tags
# 2017-05-28 13:12:08,071 : INFO : PROGRESS: at example #990000, processed 14992547 words (1288569/s), 180066 word types, 6 tags
# 2017-05-28 13:12:08,185 : INFO : PROGRESS: at example #1000000, processed 15145830 words (1357090/s), 181052 word types, 6 tags
# 2017-05-28 13:12:08,298 : INFO : PROGRESS: at example #1010000, processed 15297685 words (1358656/s), 181991 word types, 6 tags
# 2017-05-28 13:12:08,411 : INFO : PROGRESS: at example #1020000, processed 15449857 words (1366276/s), 182886 word types, 6 tags
# 2017-05-28 13:12:08,525 : INFO : PROGRESS: at example #1030000, processed 15602115 words (1341615/s), 183854 word types, 6 tags
# 2017-05-28 13:12:08,640 : INFO : PROGRESS: at example #1040000, processed 15753968 words (1338118/s), 184788 word types, 6 tags
# 2017-05-28 13:12:08,753 : INFO : PROGRESS: at example #1050000, processed 15905478 words (1351362/s), 185731 word types, 6 tags
# 2017-05-28 13:12:08,887 : INFO : PROGRESS: at example #1060000, processed 16058324 words (1159365/s), 186705 word types, 6 tags
# 2017-05-28 13:12:09,012 : INFO : PROGRESS: at example #1070000, processed 16209842 words (1224143/s), 187643 word types, 6 tags
# 2017-05-28 13:12:09,140 : INFO : PROGRESS: at example #1080000, processed 16362427 words (1199320/s), 188606 word types, 6 tags
# 2017-05-28 13:12:09,269 : INFO : PROGRESS: at example #1090000, processed 16512666 words (1173839/s), 189541 word types, 6 tags
# 2017-05-28 13:12:09,393 : INFO : PROGRESS: at example #1100000, processed 16664786 words (1242006/s), 190464 word types, 6 tags
# 2017-05-28 13:12:09,512 : INFO : PROGRESS: at example #1110000, processed 16816328 words (1294167/s), 191346 word types, 6 tags
# 2017-05-28 13:12:09,630 : INFO : PROGRESS: at example #1120000, processed 16968117 words (1293394/s), 192331 word types, 6 tags
# 2017-05-28 13:12:09,757 : INFO : PROGRESS: at example #1130000, processed 17120862 words (1220537/s), 193284 word types, 6 tags
# 2017-05-28 13:12:09,883 : INFO : PROGRESS: at example #1140000, processed 17271480 words (1214578/s), 194193 word types, 6 tags
# 2017-05-28 13:12:10,002 : INFO : PROGRESS: at example #1150000, processed 17423313 words (1298126/s), 195125 word types, 6 tags
# 2017-05-28 13:12:10,122 : INFO : PROGRESS: at example #1160000, processed 17575452 words (1292793/s), 196053 word types, 6 tags
# 2017-05-28 13:12:10,244 : INFO : PROGRESS: at example #1170000, processed 17726085 words (1254132/s), 196964 word types, 6 tags
# 2017-05-28 13:12:10,362 : INFO : PROGRESS: at example #1180000, processed 17879024 words (1309681/s), 197818 word types, 6 tags
# 2017-05-28 13:12:10,488 : INFO : PROGRESS: at example #1190000, processed 18030838 words (1223748/s), 198712 word types, 6 tags
# 2017-05-28 13:12:10,615 : INFO : PROGRESS: at example #1200000, processed 18183580 words (1212329/s), 199679 word types, 6 tags
# 2017-05-28 13:12:10,734 : INFO : PROGRESS: at example #1210000, processed 18335688 words (1282722/s), 200533 word types, 6 tags
# 2017-05-28 13:12:10,855 : INFO : PROGRESS: at example #1220000, processed 18488387 words (1275266/s), 201409 word types, 6 tags
# 2017-05-28 13:12:10,978 : INFO : PROGRESS: at example #1230000, processed 18640734 words (1257795/s), 202366 word types, 6 tags
# 2017-05-28 13:12:11,104 : INFO : PROGRESS: at example #1240000, processed 18792002 words (1215703/s), 203208 word types, 6 tags
# 2017-05-28 13:12:11,233 : INFO : PROGRESS: at example #1250000, processed 18943728 words (1198026/s), 204131 word types, 6 tags
# 2017-05-28 13:12:11,353 : INFO : PROGRESS: at example #1260000, processed 19096710 words (1288802/s), 205021 word types, 6 tags
# 2017-05-28 13:12:11,484 : INFO : PROGRESS: at example #1270000, processed 19249183 words (1172185/s), 205905 word types, 6 tags
# 2017-05-28 13:12:11,601 : INFO : PROGRESS: at example #1280000, processed 19401048 words (1308346/s), 206763 word types, 6 tags
# 2017-05-28 13:12:11,740 : INFO : PROGRESS: at example #1290000, processed 19552349 words (1105711/s), 207584 word types, 6 tags
# 2017-05-28 13:12:11,860 : INFO : PROGRESS: at example #1300000, processed 19704372 words (1275357/s), 208424 word types, 6 tags
# 2017-05-28 13:12:11,980 : INFO : PROGRESS: at example #1310000, processed 19856846 words (1283396/s), 209231 word types, 6 tags
# 2017-05-28 13:12:12,095 : INFO : PROGRESS: at example #1320000, processed 20009768 words (1337167/s), 210081 word types, 6 tags
# 2017-05-28 13:12:12,211 : INFO : PROGRESS: at example #1330000, processed 20161402 words (1321391/s), 210931 word types, 6 tags
# 2017-05-28 13:12:12,328 : INFO : PROGRESS: at example #1340000, processed 20314694 words (1328277/s), 211777 word types, 6 tags
# 2017-05-28 13:12:12,444 : INFO : PROGRESS: at example #1350000, processed 20467097 words (1341436/s), 212568 word types, 6 tags
# 2017-05-28 13:12:12,557 : INFO : PROGRESS: at example #1360000, processed 20618200 words (1350585/s), 213297 word types, 6 tags
# 2017-05-28 13:12:12,672 : INFO : PROGRESS: at example #1370000, processed 20769817 words (1333533/s), 214148 word types, 6 tags
# 2017-05-28 13:12:12,787 : INFO : PROGRESS: at example #1380000, processed 20920432 words (1315504/s), 214945 word types, 6 tags
# 2017-05-28 13:12:12,902 : INFO : PROGRESS: at example #1390000, processed 21073396 words (1346598/s), 215775 word types, 6 tags
# 2017-05-28 13:12:13,013 : INFO : PROGRESS: at example #1400000, processed 21226015 words (1387048/s), 216608 word types, 6 tags
# 2017-05-28 13:12:13,126 : INFO : PROGRESS: at example #1410000, processed 21378945 words (1375117/s), 217470 word types, 6 tags
# 2017-05-28 13:12:13,238 : INFO : PROGRESS: at example #1420000, processed 21531730 words (1377588/s), 218254 word types, 6 tags
# 2017-05-28 13:12:13,353 : INFO : PROGRESS: at example #1430000, processed 21684419 words (1348973/s), 219051 word types, 6 tags
# 2017-05-28 13:12:13,468 : INFO : PROGRESS: at example #1440000, processed 21837799 words (1354238/s), 219880 word types, 6 tags
# 2017-05-28 13:12:13,581 : INFO : PROGRESS: at example #1450000, processed 21988752 words (1347416/s), 220696 word types, 6 tags
# 2017-05-28 13:12:13,695 : INFO : PROGRESS: at example #1460000, processed 22140570 words (1345507/s), 221545 word types, 6 tags
# 2017-05-28 13:12:13,809 : INFO : PROGRESS: at example #1470000, processed 22292873 words (1355038/s), 222359 word types, 6 tags
# 2017-05-28 13:12:13,922 : INFO : PROGRESS: at example #1480000, processed 22444923 words (1351705/s), 223120 word types, 6 tags
# 2017-05-28 13:12:14,036 : INFO : PROGRESS: at example #1490000, processed 22598577 words (1370239/s), 223949 word types, 6 tags
# 2017-05-28 13:12:14,148 : INFO : PROGRESS: at example #1500000, processed 22749691 words (1360808/s), 224747 word types, 6 tags
# 2017-05-28 13:12:14,262 : INFO : PROGRESS: at example #1510000, processed 22902071 words (1357705/s), 225539 word types, 6 tags
# 2017-05-28 13:12:14,378 : INFO : PROGRESS: at example #1520000, processed 23054511 words (1341695/s), 226318 word types, 6 tags
# 2017-05-28 13:12:14,491 : INFO : PROGRESS: at example #1530000, processed 23207002 words (1366524/s), 227062 word types, 6 tags
# 2017-05-28 13:12:14,607 : INFO : PROGRESS: at example #1540000, processed 23359098 words (1331843/s), 227878 word types, 6 tags
# 2017-05-28 13:12:14,722 : INFO : PROGRESS: at example #1550000, processed 23511809 words (1347464/s), 228632 word types, 6 tags
# 2017-05-28 13:12:14,837 : INFO : PROGRESS: at example #1560000, processed 23663085 words (1335437/s), 229348 word types, 6 tags
# 2017-05-28 13:12:14,952 : INFO : PROGRESS: at example #1570000, processed 23815707 words (1335321/s), 230162 word types, 6 tags
# 2017-05-28 13:12:15,066 : INFO : PROGRESS: at example #1580000, processed 23968372 words (1358965/s), 230907 word types, 6 tags
# 2017-05-28 13:12:15,181 : INFO : PROGRESS: at example #1590000, processed 24120807 words (1349031/s), 231623 word types, 6 tags
# 2017-05-28 13:12:15,296 : INFO : PROGRESS: at example #1600000, processed 24273827 words (1334893/s), 232346 word types, 6 tags
# 2017-05-28 13:12:15,411 : INFO : PROGRESS: at example #1610000, processed 24424793 words (1329987/s), 233098 word types, 6 tags
# 2017-05-28 13:12:15,525 : INFO : PROGRESS: at example #1620000, processed 24576719 words (1342208/s), 233786 word types, 6 tags
# 2017-05-28 13:12:15,638 : INFO : PROGRESS: at example #1630000, processed 24728625 words (1357800/s), 234537 word types, 6 tags
# 2017-05-28 13:12:15,753 : INFO : PROGRESS: at example #1640000, processed 24880904 words (1335266/s), 235229 word types, 6 tags
# 2017-05-28 13:12:15,870 : INFO : PROGRESS: at example #1650000, processed 25032375 words (1313030/s), 235976 word types, 6 tags
# 2017-05-28 13:12:15,983 : INFO : PROGRESS: at example #1660000, processed 25185860 words (1364773/s), 236666 word types, 6 tags
# 2017-05-28 13:12:16,095 : INFO : PROGRESS: at example #1670000, processed 25337894 words (1370944/s), 237416 word types, 6 tags
# 2017-05-28 13:12:16,210 : INFO : PROGRESS: at example #1680000, processed 25489775 words (1349135/s), 238172 word types, 6 tags
# 2017-05-28 13:12:16,324 : INFO : PROGRESS: at example #1690000, processed 25642710 words (1358223/s), 238933 word types, 6 tags
# 2017-05-28 13:12:16,439 : INFO : PROGRESS: at example #1700000, processed 25796327 words (1345810/s), 239700 word types, 6 tags
# 2017-05-28 13:12:16,552 : INFO : PROGRESS: at example #1710000, processed 25949941 words (1368627/s), 240402 word types, 6 tags
# 2017-05-28 13:12:16,665 : INFO : PROGRESS: at example #1720000, processed 26102440 words (1363529/s), 241160 word types, 6 tags
# 2017-05-28 13:12:16,779 : INFO : PROGRESS: at example #1730000, processed 26254324 words (1349081/s), 241916 word types, 6 tags
# 2017-05-28 13:12:16,894 : INFO : PROGRESS: at example #1740000, processed 26406286 words (1326914/s), 242621 word types, 6 tags
# 2017-05-28 13:12:17,009 : INFO : PROGRESS: at example #1750000, processed 26558906 words (1349580/s), 243261 word types, 6 tags
# 2017-05-28 13:12:17,123 : INFO : PROGRESS: at example #1760000, processed 26709915 words (1339501/s), 243980 word types, 6 tags
# 2017-05-28 13:12:17,238 : INFO : PROGRESS: at example #1770000, processed 26863013 words (1347031/s), 244660 word types, 6 tags
# 2017-05-28 13:12:17,355 : INFO : PROGRESS: at example #1780000, processed 27016138 words (1329491/s), 245311 word types, 6 tags
# 2017-05-28 13:12:17,476 : INFO : PROGRESS: at example #1790000, processed 27168520 words (1273453/s), 246022 word types, 6 tags
# 2017-05-28 13:12:17,598 : INFO : PROGRESS: at example #1800000, processed 27320825 words (1261347/s), 246700 word types, 6 tags
# 2017-05-28 13:12:17,653 : INFO : collected 246991 word types and 6 unique tags from a corpus of 1804600 examples and 27391535 words
# 2017-05-28 13:12:17,654 : INFO : Loading a fresh vocabulary
# 2017-05-28 13:12:21,693 : INFO : min_count=5 retains 55205 unique words (22% of original 246991, drops 191786)
# 2017-05-28 13:12:21,695 : INFO : min_count=5 leaves 27097842 word corpus (98% of original 27391535, drops 293693)
# 2017-05-28 13:12:22,187 : INFO : deleting the raw counts dictionary of 246991 items
# 2017-05-28 13:12:22,225 : INFO : sample=0.001 downsamples 46 most-common words
# 2017-05-28 13:12:22,236 : INFO : downsampling leaves estimated 18425958 word corpus (68.0% of prior 27097842)
# 2017-05-28 13:12:22,237 : INFO : estimated required memory for 55205 words and 5 dimensions: 29812020 bytes
# 2017-05-28 13:12:22,597 : INFO : resetting layer weights
# 2017-05-28 13:12:23,768 : INFO : training model with 1 workers on 55205 vocabulary and 5 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-05-28 13:50:34,436 : INFO : training on 547830700 raw words (404615476 effective words) took 2290.6s, 176644 effective words/s

# %% [markdown]
# Interesting thing about doc2vec is that we need to run gradient descent during prediction to infer the vector for an unseen document. An unseen document is initially assigned a random vector and then this vector fit by gradient descent. Because of this randomness we get different vectors on re-runs of the next cell.
#
# Consequently, the accuracy of logistic regression changes when the test set vectors change.

# %%
# %%time
test_targets, test_regressors = zip(
    *[(doc.tags[0], doc2vec_model.infer_vector(doc.words, steps=20)) for doc in testsent])

# %%
sgd = linear_model.SGDClassifier(n_iter=20)
sgd = sgd.fit(train_regressors, train_targets)
evaluate_prediction(sgd.predict(test_regressors), test_targets, le)

# %%
doc2vec_model.docvecs.most_similar('anger')

# %%
doc2vec_model.most_similar([doc2vec_model.docvecs['fear']])

# %% [markdown]
# ## Deep IR
#
# 'Deep IR' is a technique developed by “Document Classification by Inversion of Distributed Language Representations”, Matt Taddy. Matt has contributed a gensim tutorial - great source of more in depth information.
#
# In short the algorithm is:
#
# 1. Train a word2vec model only on comedy plots.
# 2. Trian another model only on sci-fi, another on romance etc. Get 6 models - one for each genre.
# 3. Take a plot and see which model fits it best using Bayes' Theorem
#
# The tokenization is different from other methods. The reason for this is that we are following an original approach in the paper. The purpose of this tutorial is to see how the models behave out of the box.
#
# We just clean non-alphanumeric characters and split by sentences.

# %%
import re
contractions = re.compile(r"'|-|\"")
# all non alphanumeric
symbols = re.compile(r'(\W+)', re.U)
# single character removal
singles = re.compile(r'(\s\S\s)', re.I|re.U)
# separators (any whitespace)
seps = re.compile(r'\s+')

# cleaner (order matters)
def clean(text): 
    text = text.lower()
    text = contractions.sub('', text)
    text = symbols.sub(r' \1 ', text)
    text = singles.sub(' ', text)
    text = seps.sub(' ', text)
    return text

# sentence splitter
alteos = re.compile(r'([!\?])')
def sentences(l):
    l = alteos.sub(r' \1 .', l).rstrip("(\.)*\n")
    return l.split(".")

# %%
def plots(label):
    my_df = None
    if label=='training':
        my_df = train_data
    else:
        my_df = test_data
    for i, row in my_df.iterrows():
        yield {'y':row['emotions'],\
        'x':[clean(s).split() for s in sentences(row['text'])]}

# %%
# %%time
# The corpus is small so can be read into memory
revtrain = list(plots("training"))
revtest = list(plots("test"))

# %%
# shuffle training set for unbiased word2vec training
np.random.shuffle(revtrain)

# %%
my_tags = le.classes_

# %%
def tag_sentences(reviews, stars=my_tags):  
    for r in reviews:
        if r['y'] in stars:
            for s in r['x']:
                yield s

# %%
next(tag_sentences(revtrain, my_tags[0]))

# %%
# %%time 
## training
from gensim.models import Word2Vec
import multiprocessing

## create a w2v learner 
basemodel = Word2Vec(
    workers=multiprocessing.cpu_count(), # use your cores
    iter=100, # iter = sweeps of SGD through the data; more is better
    hs=1, negative=0, # we only have scoring for the hierarchical softmax setup
    
    )
print(basemodel)
basemodel.build_vocab(tag_sentences(revtrain)) 
from copy import deepcopy
genremodels = [deepcopy(basemodel) for i in range(len(my_tags))]
for i in range(len(my_tags)):
    slist = list(tag_sentences(revtrain, my_tags[i]))
    print(my_tags[i], "emotion (", len(slist), ")")
    genremodels[i].train(slist, total_examples=len(slist), epochs=100 )
# get the probs (note we give docprob a list of lists of words, plus the models)

# %% [markdown]
# Now we will compute most likely class for a plot using Bayes' Theorem formula.
#
# For any new sentence we can obtain its likelihood (lhd; actually, the composite likelihood approximation; see the paper) using the score function in the word2vec class. We get the likelihood for each sentence in the first test review, then convert to a probability over star ratings. Every sentence in the review is evaluated separately and the final star rating of the review is an average vote of all the sentences. This is all in the following handy wrapper. (from the original tutorial by Matt Taddy.

# %%
"""
docprob takes two lists
* docs: a list of documents, each of which is a list of sentences
* models: the candidate word2vec models (each potential class)

it returns the array of class probabilities.  Everything is done in-memory.
"""


def docprob(docs, mods):
    # score() takes a list [s] of sentences here; could also be a sentence generator
    sentlist = [s for d in docs for s in d]
    # the log likelihood of each sentence in this review under each w2v representation
    llhd = np.array( [ m.score(sentlist, len(sentlist)) for m in mods ] )
    # now exponentiate to get likelihoods, 
    lhd = np.exp(llhd - llhd.max(axis=0)) # subtract row max to avoid numeric overload
    # normalize across models (stars) to get sentence-star probabilities
    prob = pd.DataFrame( (lhd/lhd.sum(axis=0)).transpose() )
    # and finally average the sentence probabilities to get the review probability
    prob["doc"] = [i for i,d in enumerate(docs) for s in d]
    prob = prob.groupby("doc").mean()
    return prob

# %%
# %%time
## predict
probs = docprob( [r['x'] for r in revtest], genremodels )  
predictions = probs.idxmax(axis=1).apply(lambda x: my_tags[x])

# %%
tag_index = 0
col_name = "out-of-sample prob positive for " + my_tags[tag_index]
probpos = pd.DataFrame({col_name:probs[[tag_index]].sum(axis=1), 
                        "true genres": [r['y'] for r in revtest]})
probpos.boxplot(col_name,by="true genres", figsize=(12,5))

# %%
target = [r['y'] for r in revtest]

# %%
evaluate_prediction(predictions, target, le)

# %% [markdown]
# # Fasttext
#
# https://github.com/salestock/fastText.py

# %% [markdown]
# ### Train models
#
# For training the models yourself, you'll need to have both Gensim and FastText set up on your machine.

# %%
import fasttext

# %%
def mlb_order(pred_prob, mlb_classes):
    res = np.zeros(len(mlb_classes))
    for prob in pred_prob:
        res[np.where(mlb_classes == prob[0])] = prob[1]
    return res.tolist()

# %%
target = test_data.emotions.values

# %%
train_data['label'] = ['__label__' + str(label) for label in train_data.emotions]
test_data['label'] = ['__label__' + str(label) for label in test_data.emotions]

# %%
train_data[['label', 'text']].to_csv('./fasttext/train.txt', index=False, header=None, sep=' ')
test_data[['label', 'text']].to_csv('./fasttext/test.txt', index=False, header=None, sep=' ')

# %%
classifier = fasttext.supervised('fasttext/train.txt', 'model', epoch=10, dim=300)

# %%
result = classifier.predict(test_data.text.values)

# %%
predictions = [res[0] for res in result]

# %%
evaluate_prediction(predictions, target, le)
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.41      0.31      0.35       107
#        fear       0.18      0.43      0.25        87
#         joy       0.72      0.36      0.48       456
#     sadness       0.36      0.53      0.43       165
#    surprise       0.24      0.17      0.20       125
#       trust       0.27      0.50      0.35       102
#
# avg / total       0.48      0.38      0.39      1042
#
# Accuracy:
# 0.379078694818

# %%
fasttext_pred_prob = classifier.predict_proba(test_data.text.values, len(emotions))

# %%
fasttext_pred_prob[0]
# Out:
# [('sadness', 0.380859),
#  ('trust', 0.333984),
#  ('joy', 0.169922),
#  ('fear', 0.0742188),
#  ('surprise', 0.0214844),
#  ('anger', 0.0136719)]

# %%
mlb.classes_
# Out:
# array(['anger', 'fear', 'joy', 'sadness', 'surprise', 'trust'], dtype=object)

# %%
fasttext_prob_mlb = [mlb_order(pred_prob, mlb.classes_) for pred_prob in fasttext_pred_prob]

# %%
average_precision_score(y_bin_emotions, fasttext_prob_mlb)
# Out:
# 0.43511258556124094

# %%
label_ranking_average_precision_score(y_bin_emotions, fasttext_prob_mlb)
# Out:
# 0.64302889741949409

# %%
label_ranking_loss(y_bin_emotions, fasttext_prob_mlb)
# Out:
# 0.30066645340157822

# %%
target_full = [set(t) - {np.nan} for t in tweets[['emo1','emo2','emo3']].values]

# %%
pred = [set(pred) for pred in classifier.predict(test_data.text.values, 1)]
sum([len(target_full[i] & pred[i])>0 for i in range(len(pred))]) / len(test_data)
# Out:
# 0.491362763915547

# %%
pred = [set(pred) for pred in classifier.predict(test_data.text.values, 2)]
sum([len(target_full[i] & pred[i])>0 for i in range(len(pred))]) / len(test_data)
# Out:
# 0.7072936660268714

# %%
pred = [set(pred) for pred in classifier.predict(test_data.text.values, 3)]
sum([len(target_full[i] & pred[i])>0 for i in range(len(pred))]) / len(test_data)
# Out:
# 0.8272552783109405

# %%
def prob_validation(pred, target):
    if pred[0] in target:
        return pred[1]
    return 0

# %%
pred = [pred[0] for pred in classifier.predict_proba(test_data.text.values, 1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a5f4db4f2422> in <module>()
# ----> 1 pred = [pred[0] for pred in classifier.predict_proba(test_data.text.values, 1)]
#
# NameError: name 'classifier' is not defined

# %%
sum([prob_validation(pred[i], target[i]) for i in range(len(pred))]) / sum(list(zip(*pred))[1])
# Out:
# 0.41039154375911274

# %% [markdown]
# ```
# ~/fastText/fasttext supervised -input train.txt -output output -minn 3
# -maxn 6
# ~/fastText/fasttext predict-prob output.bin test.txt 6 > res.txt
# ```

# %%
custom_results = pd.read_csv('./fasttext/res.txt', names=['pred_pob'])
custom_fasttext_prob = custom_results.pred_pob.apply(lambda pred: [tuple(p.split(' ')[:2]) for p in pred.split('__label__')[1:]]).tolist()
custom_pred = [pred[0][0] for pred in custom_fasttext_prob]
evaluate_prediction(custom_pred, target, le)
custom_prob_mlb = [mlb_order(pred, mlb.classes_) for pred in custom_fasttext_prob]
print('average_precision_score: %f' % average_precision_score(y_bin_emotions, custom_prob_mlb))
print('label_ranking_average_precision_score: %f' % label_ranking_average_precision_score(y_bin_emotions, custom_prob_mlb))
print('label_ranking_loss: %f' %label_ranking_loss(y_bin_emotions, custom_prob_mlb))
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.42      0.33      0.37       107
#        fear       0.16      0.41      0.23        87
#         joy       0.74      0.39      0.51       456
#     sadness       0.35      0.51      0.42       165
#    surprise       0.26      0.19      0.22       125
#       trust       0.30      0.46      0.36       102
#
# avg / total       0.50      0.39      0.41      1042
#
# Accuracy:
# 0.389635316699
# average_precision_score: 0.449240
# label_ranking_average_precision_score: 0.656872
# label_ranking_loss: 0.282600
