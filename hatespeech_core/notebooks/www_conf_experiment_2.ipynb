# %% [markdown]
# # WWW Experiements
#
# Here we try to do some additional experiments for evaluating and comparing to other approaches.
#
# #### Story #2
#
# There's one other possible approach called sense2vec. I think I mentioned it some time. Anyway it's for word sense disambiguation. You can get a quick overview here https://explosion.ai/blog/sense2vec-with-spacy
#
# What if I were to train this, and use the code words from the survey and their specific part of speech tag to contrast the output from both methods. So I would be comparing directly with the sense2vec word similarity output.

# %%
import sys
sys.path.append("../")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob, os, joblib
import pandas as pd
from pprint import pprint
from gensim.models import KeyedVectors, Word2Vec
from modules.preprocessing import neural_embeddings
from modules.utils import file_ops, model_helpers, settings

# %% [markdown]
# #### Load code words

# %%
hs_keywords = set(file_ops.read_csv_file("refined_hs_keywords", settings.TWITTER_SEARCH_PATH))
df_primary = pd.DataFrame.from_csv(settings.CW_SEARCH_PATH + "primary_cw_search_results.csv")
df_secondary = pd.DataFrame.from_csv(settings.CW_SEARCH_PATH + "secondary_cw_search_results.csv")
primary_set = set(df_primary['primary'].tolist())
secondary_set = set(df_secondary['secondary'].tolist())
codeword_set = primary_set.union(secondary_set)

# %% [markdown]
# #### Load Embeddings

# %%
sens2vec = Word2Vec.load(settings.EMBEDDING_MODELS + "sense2vec_core_hate_corpus")

# %%
sens2vec.similar_by_word("creatures", topn=20)
# Out:
# [('attractive', 0.9933284521102905),
#  ('apes', 0.9914869070053101),
#  ('plenty', 0.9877194166183472),
#  ('emotions', 0.9871485233306885),
#  ('behaving', 0.9860166311264038),
#  ('brains', 0.985710620880127),
#  ('gays', 0.9856736660003662),
#  ('cancer', 0.9851076602935791),
#  ('blind', 0.9842312335968018),
#  ('differently', 0.9841403961181641),
#  ('drives', 0.9840661287307739),
#  ('teach', 0.9837367534637451),
#  ('poison', 0.9836177825927734),
#  ('crusades', 0.9835742712020874),
#  ('hearts', 0.9835299253463745),
#  ('perverts', 0.9833177328109741),
#  ('complain', 0.9831520318984985),
#  ('pakis', 0.9829404354095459),
#  ('psychologically', 0.9824094772338867),
#  ('excuses', 0.9823436737060547)]

# %%
pprint(list(sens2vec.wv.vocab.keys()))
# Out:
# ['violent|ADJ',
#  'mike|NOUN',
#  '?|PUNCT',
#  'a|DET',
#  'version|NOUN',
#  'by|ADP',
#  'obamacare|NOUN',
#  'surprise|NOUN',
#  'throw|VERB',
#  'leads|VERB',
#  'picture|NOUN',
#  'common|ADJ',
#  'msm|NOUN',
#  'running|VERB',
#  'quite|ADV',
#  'pool|NOUN',
#  'iq|NOUN',
#  'read|VERB',
#  'were|VERB',
#  'usually|ADV',
#  'rest|NOUN',
#  '2015|DATE',
#  'green|ADJ',
#  'keeps|VERB',
#  'rarely|ADV',
#  'dirty|ADJ',
#  'clear|ADJ',
#  'conservatives|NOUN',
#  'school|NOUN',
#  'its|ADJ',
#  'like|VERB',
#  'shall|VERB',
#  'few|ADJ',
#  'calling|VERB',
#  'south_africa|NOUN',
#  'group|NOUN',
#  'matter|NOUN',
#  'leaving|VERB',
#  'professor|NOUN',
#  'media|NOUN',
#  're|VERB',
#  'crazy|ADJ',
#  'negroes|NOUN',
#  'but|ADP',
#  'bed|NOUN',
#  'leftism|NOUN',
#  'sing|VERB',
#  'cucks|NOUN',
#  'birthday|NOUN',
#  'either|CONJ',
#  'goes|VERB',
#  'garbage|NOUN',
#  'himself|PRON',
#  'rid|VERB',
#  'scum|NOUN',
#  'nah|INTJ',
#  '18|CARDINAL',
#  'be|VERB',
#  'right|NOUN',
#  'criminals|NOUN',
#  'racists|NOUN',
#  'over|ADP',
#  'funny|ADJ',
#  'win|NOUN',
#  'jew|PROPN',
#  '—|PUNCT',
#  'south|ADJ',
#  'catholic_church|NOUN',
#  'accept|VERB',
#  'american|ADJ',
#  'tcot|NOUN',
#  'easy|ADJ',
#  'welcome|NOUN',
#  'rule|VERB',
#  'dogs|NOUN',
#  'gender|NOUN',
#  'typical|ADJ',
#  'lied|VERB',
#  'out|ADP',
#  'goal|NOUN',
#  'debate|NOUN',
#  'room|NOUN',
#  'days|NOUN',
#  'communism|NOUN',
#  'shot|VERB',
#  'fine|ADJ',
#  'white_men|NOUN',
#  'total|ADJ',
#  'reject|VERB',
#  'boots|NOUN',
#  'have|VERB',
#  'thousands|CARDINAL',
#  'law|NOUN',
#  'world|NOUN',
#  'eu|PROPN',
#  'gonna|ADV',
#  'simply|ADV',
#  'safety|NOUN',
#  'house|NOUN',
#  'missed|VERB',
#  'open|ADJ',
#  'u.s|PROPN',
#  'difference|NOUN',
#  'teach|VERB',
#  'podcast|NOUN',
#  'israel|NOUN',
#  'changed|VERB',
#  'birth|NOUN',
#  'probably|ADV',
#  'reality|NOUN',
#  'starts|VERB',
#  'responsibility|NOUN',
#  'white|ADJ',
#  'ca|VERB',
#  'fire|NOUN',
#  'live|ADV',
#  'jews|PROPN',
#  'child|NOUN',
#  'lived|VERB',
#  'nigger|NOUN',
#  'police|NOUN',
#  'spend|VERB',
#  'schools|NOUN',
#  'solution|NOUN',
#  'strong|ADJ',
#  'try|VERB',
#  'cold|ADJ',
#  'streets|NOUN',
#  'nations|NOUN',
#  'em|PRON',
#  'often|ADV',
#  'russia|ENT',
#  'major|ADJ',
#  'terrorism|NOUN',
#  'smell|VERB',
#  'change|VERB',
#  's|NOUN',
#  'eye|NOUN',
#  'lives|NOUN',
#  'everyone|NOUN',
#  ':d|PUNCT',
#  'pretty|ADV',
#  'gop|NOUN',
#  'which|ADJ',
#  '=|PROPN',
#  'pope|NOUN',
#  'promote|VERB',
#  'putin|NOUN',
#  'o|NOUN',
#  'too|ADV',
#  'office|NOUN',
#  'spirit|NOUN',
#  'illegals|NOUN',
#  "'re|VERB",
#  'honour|NOUN',
#  'deserve|VERB',
#  'beating|VERB',
#  'mr|NOUN',
#  'election|NOUN',
#  'african|ADJ',
#  'post|VERB',
#  'user_mention|ADP',
#  'next|ADJ',
#  'cover|VERB',
#  'charges|NOUN',
#  'bag|NOUN',
#  'feeling|VERB',
#  'bush|NOUN',
#  'dems|NOUN',
#  'different|ADJ',
#  'cop|NOUN',
#  'thought|NOUN',
#  'level|NOUN',
#  'hammer|NOUN',
#  'white_country|NOUN',
#  'outrage|NOUN',
#  '$|SYM',
#  'properly|ADV',
#  'negro|ADJ',
#  'since|ADP',
#  'heard|VERB',
#  'record|NOUN',
#  'own_country|NOUN',
#  'privilege|NOUN',
#  'deaths|NOUN',
#  'agree|VERB',
#  'youtube|NOUN',
#  'thread|NOUN',
#  'asia|NOUN',
#  "'|PART",
#  'ago|ADV',
#  'racist|NOUN',
#  'no|INTJ',
#  'turned|VERB',
#  'night|NOUN',
#  'lost|VERB',
#  'lack|NOUN',
#  'killed|VERB',
#  'retarded|ADJ',
#  'mad|ADJ',
#  'user_mention|ADJ',
#  'wants|VERB',
#  'al|PROPN',
#  'hope|NOUN',
#  'banning|VERB',
#  'public|ADJ',
#  'lies|NOUN',
#  'stay|VERB',
#  '6|CARDINAL',
#  'x|SYM',
#  'girl|NOUN',
#  'ridiculous|ADJ',
#  'cops|NOUN',
#  'wanted|VERB',
#  'jewish|ADJ',
#  'moved|VERB',
#  'disgrace|NOUN',
#  'anyone|NOUN',
#  'knows|VERB',
#  'unions|NOUN',
#  'out|ADV',
#  'interesting|ADJ',
#  'state|NOUN',
#  'before|ADV',
#  'friends|NOUN',
#  'disgusting|ADJ',
#  'deserves|VERB',
#  'it|PRON',
#  'credit|NOUN',
#  'free_speech|NOUN',
#  'all|ADJ',
#  'mexicans|NOUN',
#  'not|ADV',
#  'idiot|NOUN',
#  'hey|INTJ',
#  'walking|VERB',
#  'gonna|ADJ',
#  'jew|NOUN',
#  'although|ADP',
#  'sun|NOUN',
#  'plan|NOUN',
#  'one|PRON',
#  'move|VERB',
#  'assault|NOUN',
#  'am|VERB',
#  'means|NOUN',
#  'first|ADV',
#  'huge|ADJ',
#  'fire|VERB',
#  'an|DET',
#  'starting|VERB',
#  'always|ADV',
#  '#|SYM',
#  'bottom|NOUN',
#  '12|CARDINAL',
#  '=|VERB',
#  'itself|PRON',
#  'necessary|ADJ',
#  'altright|NOUN',
#  'cancer|NOUN',
#  'end|NOUN',
#  'predicted|VERB',
#  'figure|VERB',
#  'today|NOUN',
#  'user_mention|NOUN',
#  'own|ADJ',
#  'three|CARDINAL',
#  'glory|NOUN',
#  'anonymous|ADJ',
#  'act|VERB',
#  'face|VERB',
#  'flag|NOUN',
#  'begin|VERB',
#  'der|NOUN',
#  'rise|NOUN',
#  'feels|VERB',
#  'undermine|VERB',
#  'welfare|NOUN',
#  'poll|NOUN',
#  'dog|NOUN',
#  'towards|ADP',
#  'equality|NOUN',
#  'road|NOUN',
#  'cost|NOUN',
#  'user_mention|PART',
#  'voters|NOUN',
#  'actually|ADV',
#  'canadians|NOUN',
#  'morning|NOUN',
#  'enemies|NOUN',
#  'immigrants|NOUN',
#  'control|VERB',
#  'wow|INTJ',
#  'raise|VERB',
#  'austria|NOUN',
#  'age|NOUN',
#  'rapists|NOUN',
#  'paul|NOUN',
#  "n't|ADV",
#  'peace|NOUN',
#  'grow|VERB',
#  'slavery|NOUN',
#  'creating|VERB',
#  'blacks|NOUN',
#  'while|ADP',
#  'goy|NOUN',
#  'no|ADV',
#  'fault|NOUN',
#  'like|INTJ',
#  'notice|VERB',
#  'god|NOUN',
#  'near|ADP',
#  'steve|NOUN',
#  'myself|PRON',
#  'sucks|VERB',
#  'handle|VERB',
#  'ha|INTJ',
#  'study|NOUN',
#  'control|NOUN',
#  'joke|NOUN',
#  'brother|NOUN',
#  'data|NOUN',
#  'otherwise|ADV',
#  'maybe|ADV',
#  'that|DET',
#  'blocked|VERB',
#  'life|NOUN',
#  'fucked|VERB',
#  'means|VERB',
#  'ice|NOUN',
#  'dear|ADJ',
#  'down|PART',
#  'rather|ADV',
#  'block|VERB',
#  'understand|VERB',
#  'completely|ADV',
#  '*|PUNCT',
#  'ethnicity|NOUN',
#  'must|VERB',
#  'hundreds|CARDINAL',
#  'live|ADJ',
#  'giving|VERB',
#  'compact|ADJ',
#  'front|NOUN',
#  'die|VERB',
#  'least|ADJ',
#  'hide|VERB',
#  'steal|VERB',
#  'up|ADP',
#  'fucking|VERB',
#  'lets|VERB',
#  'guess|VERB',
#  'citizen|NOUN',
#  'via|ADP',
#  'supporting|VERB',
#  'demand|VERB',
#  'became|VERB',
#  'wall|NOUN',
#  'user_mention_video|NOUN',
#  'respect|VERB',
#  "'s|PRON",
#  'about|ADV',
#  'threatens|VERB',
#  'present|ADJ',
#  'useless|ADJ',
#  'crimes|NOUN',
#  'find|VERB',
#  'continue|VERB',
#  'them|PRON',
#  'earth|NOUN',
#  'rape|VERB',
#  'event|NOUN',
#  'another|DET',
#  'certainly|ADV',
#  'civil_war|NOUN',
#  'raped|VERB',
#  'ran|VERB',
#  'unlike|ADP',
#  'millions|CARDINAL',
#  'ignorant|ADJ',
#  'somehow|ADV',
#  'beer|NOUN',
#  'perhaps|ADV',
#  'proves|VERB',
#  'problem|NOUN',
#  'rape|NOUN',
#  'who|NOUN',
#  'yourself|PRON',
#  'car|NOUN',
#  'leave|VERB',
#  'guilt|NOUN',
#  'reminder|NOUN',
#  'hated|VERB',
#  'brits|NOUN',
#  '‘|PUNCT',
#  "'ll|VERB",
#  'americans|NOUN',
#  'left|NOUN',
#  'conspiracy|NOUN',
#  'prefer|VERB',
#  'murdering|VERB',
#  'taken|VERB',
#  'straight|ADV',
#  'written|VERB',
#  'say|VERB',
#  'onto|ADP',
#  'liberal|ADJ',
#  'm|VERB',
#  'battle|NOUN',
#  'over|PART',
#  'music|NOUN',
#  'truly|ADV',
#  'slut|NOUN',
#  'daddy|NOUN',
#  'tonight|TIME',
#  'waiting|VERB',
#  'faith|NOUN',
#  'uk|PROPN',
#  'enough|ADV',
#  'congress|NOUN',
#  'violence|NOUN',
#  'available|ADJ',
#  'drop|NOUN',
#  'hand|NOUN',
#  'arrived|VERB',
#  'place|NOUN',
#  'calls|VERB',
#  'there|ADV',
#  'haha|NOUN',
#  'forced|VERB',
#  "'|PUNCT",
#  'term|NOUN',
#  'clinton|NOUN',
#  'seriously|ADV',
#  'left|ADJ',
#  '2017|DATE',
#  'party|NOUN',
#  'bastards|NOUN',
#  'one|NOUN',
#  'job|NOUN',
#  'though|ADV',
#  'badly|ADV',
#  'govt|NOUN',
#  'cnn|NOUN',
#  'wake|VERB',
#  'lord|NOUN',
#  '4|CARDINAL',
#  'wikileaks|NOUN',
#  'carry|VERB',
#  'delete|VERB',
#  'nuffin|NOUN',
#  'internet|NOUN',
#  'congratulations|NOUN',
#  'we|PRON',
#  'watch|VERB',
#  'though|ADP',
#  'rights|NOUN',
#  'ok|ADJ',
#  'identity|NOUN',
#  'invite|VERB',
#  'dare|VERB',
#  'borders|NOUN',
#  'address|VERB',
#  'act|NOUN',
#  'loves|VERB',
#  ':|PUNCT',
#  'received|VERB',
#  'hit|VERB',
#  'to|PART',
#  'citizens|NOUN',
#  'know|VERB',
#  'where|ADV',
#  'question|NOUN',
#  'refused|VERB',
#  'gotta|VERB',
#  'easier|ADJ',
#  'get|VERB',
#  'others|NOUN',
#  '’s|X',
#  'invasion|NOUN',
#  'anti|ADJ',
#  'riots|NOUN',
#  'some|DET',
#  'far|ADV',
#  'supports|VERB',
#  'dindu|VERB',
#  'time|NOUN',
#  'was|VERB',
#  'pence|NOUN',
#  'news|NOUN',
#  'video|NOUN',
#  'made|VERB',
#  'he|PRON',
#  'this|DET',
#  'write|VERB',
#  'or|CONJ',
#  'issue|NOUN',
#  'bolsheviks|NOUN',
#  'uk|NOUN',
#  'responsible|ADJ',
#  'high|ADJ',
#  'merkel|NOUN',
#  'hating|VERB',
#  'big|ADJ',
#  'cause|VERB',
#  'me|PRON',
#  'won|VERB',
#  'wrote|VERB',
#  'food|NOUN',
#  'including|VERB',
#  'kill|VERB',
#  'pic|NOUN',
#  '…|PUNCT',
#  'nazi|NOUN',
#  'falls|VERB',
#  'above|ADP',
#  'during|ADP',
#  'puts|VERB',
#  'less|ADV',
#  'hate|NOUN',
#  'social|ADJ',
#  'send|VERB',
#  'funding|VERB',
#  '~|PUNCT',
#  'open|VERB',
#  'breath|NOUN',
#  '.…|PUNCT',
#  'polls|NOUN',
#  'so|ADV',
#  'right|ADJ',
#  'help|VERB',
#  'off|ADP',
#  'art|NOUN',
#  'propaganda|NOUN',
#  'phone|NOUN',
#  'lots|NOUN',
#  'mind|NOUN',
#  'security|NOUN',
#  'released|VERB',
#  'beyond|ADP',
#  'leftists|NOUN',
#  'signed|VERB',
#  'worse|ADJ',
#  'prison|NOUN',
#  'tell|VERB',
#  'bottle|NOUN',
#  '2|CARDINAL',
#  'thank|VERB',
#  'wait|VERB',
#  'killers|NOUN',
#  'true|ADJ',
#  'explain|VERB',
#  'listening|VERB',
#  'remove|VERB',
#  'bill|NOUN',
#  'return|NOUN',
#  'appreciate|VERB',
#  'report|VERB',
#  'arms|NOUN',
#  'intended|VERB',
#  'loved|VERB',
#  'folks|NOUN',
#  'r|NOUN',
#  'watching|VERB',
#  'democrats|NOUN',
#  'un|NOUN',
#  ':(|PUNCT',
#  'swedes|NOUN',
#  'politically|ADV',
#  'definition|NOUN',
#  'ai|VERB',
#  'winning|VERB',
#  'those|DET',
#  'truck|NOUN',
#  'matters|VERB',
#  'care|VERB',
#  'called|VERB',
#  'expected|VERB',
#  'strength|NOUN',
#  'speak|VERB',
#  'apparently|ADV',
#  'swastika|NOUN',
#  'you|PRON',
#  'hypocrisy|NOUN',
#  'boy|NOUN',
#  'allegiance|NOUN',
#  'alone|ADV',
#  'u|PRON',
#  'somewhere|ADV',
#  'why|ADV',
#  'sister|NOUN',
#  'new|ADJ',
#  'hi|INTJ',
#  'user_mention_user_mention_user_mention_user_mention|NOUN',
#  'citizenship|NOUN',
#  'consider|VERB',
#  "'d|VERB",
#  'user_mention_trump|NOUN',
#  'jail|NOUN',
#  'obvious|ADJ',
#  'proof|NOUN',
#  'case|NOUN',
#  '’|PUNCT',
#  'her|PRON',
#  'definitely|ADV',
#  'communist|ADJ',
#  'germans|NOUN',
#  'matter|ADV',
#  'shirt|NOUN',
#  '“|PUNCT',
#  'work|NOUN',
#  'alt-right|NOUN',
#  'again|ADV',
#  'can|VERB',
#  'gives|VERB',
#  'hillary|ADJ',
#  'judge|NOUN',
#  'soros|NOUN',
#  '#|NOUN',
#  'said|VERB',
#  'start|VERB',
#  'drink|VERB',
#  'russia|NOUN',
#  'lie|VERB',
#  'works|VERB',
#  'punished|VERB',
#  'ourselves|PRON',
#  'voice|NOUN',
#  'hates|VERB',
#  'hole|NOUN',
#  'sad|ADJ',
#  'racial|ADJ',
#  'u|X',
#  'wtf|NOUN',
#  'djt|NOUN',
#  'bring|VERB',
#  'agenda|NOUN',
#  'declared|VERB',
#  'wrong|ADJ',
#  'perfect|ADJ',
#  'donald|NOUN',
#  'alt|NOUN',
#  'charge|NOUN',
#  'before|ADP',
#  'play|NOUN',
#  'finished|VERB',
#  'david|NOUN',
#  'sure|ADJ',
#  'nazis|NOUN',
#  'busy|ADJ',
#  'legacy|NOUN',
#  'free|ADJ',
#  'start|NOUN',
#  'mixing|VERB',
#  'jesus|NOUN',
#  'call|VERB',
#  'kick|VERB',
#  'constitution|NOUN',
#  'hear|VERB',
#  'own_people|NOUN',
#  'happened|VERB',
#  'involved|VERB',
#  'run|VERB',
#  'same|ADJ',
#  '10_years|DATE',
#  'much|ADJ',
#  'bitch|NOUN',
#  'super|ADJ',
#  'respect|NOUN',
#  'america|NOUN',
#  'china|NOUN',
#  '’s|NUM',
#  ',|PUNCT',
#  'dumb|ADJ',
#  'bullshit|NOUN',
#  'share|VERB',
#  'burning|VERB',
#  'none|NOUN',
#  'in|ADP',
#  'left|VERB',
#  'math|NOUN',
#  'work|VERB',
#  'throwing|VERB',
#  'volume|NOUN',
#  'after|ADP',
#  'to|ADP',
#  'justice|NOUN',
#  'english|NOUN',
#  'link|NOUN',
#  'upon|ADP',
#  'beautiful|ADJ',
#  'disagree|VERB',
#  'user_mention|VERB',
#  'resign|VERB',
#  'correct|ADJ',
#  '....|PUNCT',
#  'tim|NOUN',
#  'started|VERB',
#  'liberals|NOUN',
#  'london|NOUN',
#  'pepe|NOUN',
#  'off|PART',
#  'answer|NOUN',
#  'closet|NOUN',
#  '+|CONJ',
#  'across|ADP',
#  'doctor|NOUN',
#  'fake_news|NOUN',
#  'worst|ADJ',
#  'invaded|VERB',
#  'w|NOUN',
#  'but|CONJ',
#  'filled|VERB',
#  'richard|NOUN',
#  'president_trump|NOUN',
#  'stand|VERB',
#  'burned|VERB',
#  'shut|VERB',
#  'shows|VERB',
#  'whether|ADP',
#  'him|PRON',
#  'pain|NOUN',
#  'statement|NOUN',
#  'population|NOUN',
#  'family|NOUN',
#  'mistake|NOUN',
#  'james|NOUN',
#  'air|NOUN',
#  'user_mention|X',
#  'given|VERB',
#  'working|VERB',
#  'milo|NOUN',
#  'animals|NOUN',
#  'yet|ADV',
#  'happens|VERB',
#  'fear|VERB',
#  'helps|VERB',
#  'less|ADJ',
#  'failing|VERB',
#  'today|DATE',
#  'clown|NOUN',
#  'only|ADV',
#  'off|ADV',
#  '88|CARDINAL',
#  'quotes|NOUN',
#  'because|ADP',
#  'gang|NOUN',
#  'hang|VERB',
#  'thinking|VERB',
#  'faces|NOUN',
#  'national|ADJ',
#  'immigration|NOUN',
#  'majority|NOUN',
#  'nice|ADJ',
#  'aware|ADJ',
#  'step|VERB',
#  'fbi|PROPN',
#  'clue|NOUN',
#  'play|VERB',
#  'somebody|NOUN',
#  'things|NOUN',
#  'human|ADJ',
#  'note|NOUN',
#  'setting|VERB',
#  'races|NOUN',
#  'go|VERB',
#  'expect|VERB',
#  'sjws|NOUN',
#  'talked|VERB',
#  '7|CARDINAL',
#  'headline|NOUN',
#  'dealing|VERB',
#  'followers|NOUN',
#  'gonna|NOUN',
#  'realize|VERB',
#  'wanting|VERB',
#  'part|NOUN',
#  'fake|ADJ',
#  'watch|NOUN',
#  'band|NOUN',
#  'up|PART',
#  'hey|ADJ',
#  'bunch|NOUN',
#  'values|NOUN',
#  'speaking|VERB',
#  'believes|VERB',
#  '3|CARDINAL',
#  'letting|VERB',
#  'rob|VERB',
#  'eu|NOUN',
#  'usa|NOUN',
#  'day|NOUN',
#  'showing|VERB',
#  'better|ADJ',
#  'ways|NOUN',
#  'lead|VERB',
#  'holds|VERB',
#  'matter|VERB',
#  'should|VERB',
#  'door|NOUN',
#  'fuck|VERB',
#  'seeing|VERB',
#  'going|VERB',
#  'important|ADJ',
#  'losers|NOUN',
#  'head|NOUN',
#  'many|ADJ',
#  'kind|NOUN',
#  'black_man|NOUN',
#  'forgot|VERB',
#  'hard|ADJ',
#  'students|NOUN',
#  'open_borders|NOUN',
#  'believe|VERB',
#  'hillary|PROPN',
#  'boys|NOUN',
#  'scared|VERB',
#  'fill|VERB',
#  'suck|VERB',
#  'lucky|ADJ',
#  'audio|NOUN',
#  'mass|NOUN',
#  'info|NOUN',
#  'nazi|ADJ',
#  'says|VERB',
#  'support|NOUN',
#  '11|CARDINAL',
#  'listen|VERB',
#  'honestly|ADV',
#  'bet|VERB',
#  'having|VERB',
#  ';)|PUNCT',
#  'both|DET',
#  'of|ADP',
#  '...|PUNCT',
#  'restore|VERB',
#  'crap|NOUN',
#  'late|ADJ',
#  'god|INTJ',
#  'conference|NOUN',
#  'sound|NOUN',
#  'drunk|ADJ',
#  'selling|VERB',
#  'spent|VERB',
#  'countries|NOUN',
#  'show|NOUN',
#  'n|CONJ',
#  'conservative|ADJ',
#  'set|VERB',
#  'apply|VERB',
#  'this_year|DATE',
#  'sent|VERB',
#  'bus|NOUN',
#  'how|ADV',
#  'cuck|NOUN',
#  'civilization|NOUN',
#  'terrorist|NOUN',
#  'obviously|ADV',
#  'deny|VERB',
#  'islamists|NOUN',
#  'user_mention_user_mention_user_mention_user_mention_user_mention|NOUN',
#  'hard|ADV',
#  'so|CONJ',
#  'looks|VERB',
#  'dying|VERB',
#  'baby|NOUN',
#  'happening|VERB',
#  'trump|NOUN',
#  'numbers|NOUN',
#  'just|ADV',
#  'release|VERB',
#  'voted|VERB',
#  'movement|NOUN',
#  'as|ADP',
#  'what|ADJ',
#  'united_states|NOUN',
#  'murder|NOUN',
#  'account|NOUN',
#  'credibility|NOUN',
#  'taking|VERB',
#  'bound|VERB',
#  'israel|PROPN',
#  'revolution|NOUN',
#  'reason|NOUN',
#  'okay|INTJ',
#  'invented|VERB',
#  'the|DET',
#  '’s|ADJ',
#  'brussels|NOUN',
#  '️|X',
#  'orders|NOUN',
#  'exist|VERB',
#  'most|ADJ',
#  'homeland|NOUN',
#  'australia|NOUN',
#  'eyes|NOUN',
#  'growing|VERB',
#  'wear|VERB',
#  'back|ADV',
#  'shoot|VERB',
#  'agreed|VERB',
#  'attacked|VERB',
#  'looking|VERB',
#  'britain|NOUN',
#  'pay|VERB',
#  'forever|ADV',
#  'fam|NOUN',
#  'taught|VERB',
#  'really|ADV',
#  'humans|NOUN',
#  'between|ADP',
#  'word|NOUN',
#  'change|NOUN',
#  'stands|VERB',
#  'your|ADJ',
#  'issues|NOUN',
#  'simple|ADJ',
#  'badge|NOUN',
#  'fbi|NOUN',
#  'john|NOUN',
#  'also|ADV',
#  'ready|ADJ',
#  'tool|NOUN',
#  'went|VERB',
#  'kek|NOUN',
#  'are|VERB',
#  'image|NOUN',
#  'sorry|ADJ',
#  'lot|NOUN',
#  'site|NOUN',
#  'user_mention|INTJ',
#  'once|ADP',
#  'words|NOUN',
#  'wish|VERB',
#  'killing|VERB',
#  'brain|NOUN',
#  'southern|ADJ',
#  'crime|NOUN',
#  'pen|NOUN',
#  'stupid|ADJ',
#  'assimilate|VERB',
#  'standard|NOUN',
#  't|NOUN',
#  'hiding|VERB',
#  '.|PUNCT',
#  'sweden|NOUN',
#  'hurt|VERB',
#  'when|ADV',
#  'arrest|NOUN',
#  '>|X',
#  'paying|VERB',
#  'eating|VERB',
#  'fear|NOUN',
#  'decided|VERB',
#  'fighting|VERB',
#  'muh|ADJ',
#  'protesters|NOUN',
#  'rioting|NOUN',
#  'his|ADJ',
#  '1|NUM',
#  'inch|NOUN',
#  'son|NOUN',
#  'belong|VERB',
#  'able|ADJ',
#  'break|VERB',
#  'red|ADJ',
#  'non|X',
#  'accused|VERB',
#  'italy|NOUN',
#  'anything|NOUN',
#  'ban|VERB',
#  'week|NOUN',
#  'died|VERB',
#  'talk|VERB',
#  'well|ADV',
#  'known|VERB',
#  'luck|NOUN',
#  'body|NOUN',
#  'merry|ADJ',
#  'christ|NOUN',
#  'despite|ADP',
#  'riot|NOUN',
#  '--|PUNCT',
#  'more|ADV',
#  'white_race|NOUN',
#  'behind|ADP',
#  'begins|VERB',
#  'charged|VERB',
#  'rules|NOUN',
#  'inside|ADP',
#  'africans|NOUN',
#  'give|VERB',
#  'cross|VERB',
#  'suicide|NOUN',
#  'imagine|VERB',
#  'pray|VERB',
#  'opposition|NOUN',
#  'long|ADJ',
#  'that|ADP',
#  'avoid|VERB',
#  'lying|VERB',
#  'class|NOUN',
#  'evil|ADJ',
#  'questions|NOUN',
#  'truth|NOUN',
#  'show|VERB',
#  'behavior|NOUN',
#  'longer|ADV',
#  'chance|NOUN',
#  'evidence|NOUN',
#  'through|ADP',
#  'guns|NOUN',
#  'live|VERB',
#  'cia|PROPN',
#  'protect|VERB',
#  'little|ADJ',
#  'brilliant|ADJ',
#  'appears|VERB',
#  'their|ADJ',
#  'therefore|ADV',
#  'crowd|NOUN',
#  'force|NOUN',
#  'couple|NOUN',
#  'worth|ADJ',
#  'city|NOUN',
#  'turns|VERB',
#  'online|ADV',
#  'had|VERB',
#  'side|NOUN',
#  'terror|NOUN',
#  'huh|INTJ',
#  'mention|VERB',
#  'politics|NOUN',
#  '-|PUNCT',
#  'isis|NOUN',
#  'liked|VERB',
#  'chaos|NOUN',
#  'ask|VERB',
#  'south|NOUN',
#  'taxes|NOUN',
#  'apologize|VERB',
#  'stats|NOUN',
#  'surrender|NOUN',
#  'held|VERB',
#  'yes|INTJ',
#  'community|NOUN',
#  'reading|VERB',
#  'property|NOUN',
#  'deal|VERB',
#  'into|ADP',
#  'against|ADP',
#  'admit|VERB',
#  'elect|VERB',
#  'whole|ADJ',
#  'win|VERB',
#  'attack|VERB',
#  'university|NOUN',
#  'coming|VERB',
#  'awesome|ADJ',
#  'make|VERB',
#  'founded|VERB',
#  'possible|ADJ',
#  'beat|VERB',
#  'declare|VERB',
#  'meant|VERB',
#  'town|NOUN',
#  'turning|VERB',
#  'fix|VERB',
#  'trust|VERB',
#  'firm|NOUN',
#  'friend|NOUN',
#  'feminists|NOUN',
#  'weird|ADJ',
#  'enough|ADJ',
#  'christianity|NOUN',
#  'unfortunately|ADV',
#  'remember|VERB',
#  'white_house|NOUN',
#  'user_mention|PUNCT',
#  'proud|ADJ',
#  'white_supremacy|NOUN',
#  'report|NOUN',
#  'gtfo|NOUN',
#  'driving|VERB',
#  'turn|VERB',
#  'western_civilization|NOUN',
#  'along|ADP',
#  'removed|VERB',
#  'kidding|VERB',
#  'yep|INTJ',
#  'woman|NOUN',
#  'fucking|ADJ',
#  'person|NOUN',
#  'radio|NOUN',
#  'referring|VERB',
#  'sold|VERB',
#  'ok|INTJ',
#  'hold|VERB',
#  'plus|CONJ',
#  'short|ADJ',
#  'took|VERB',
#  'talk|NOUN',
#  'gun|NOUN',
#  'expose|VERB',
#  'islam|NOUN',
#  'poor|ADJ',
#  'hoax|NOUN',
#  'russians|NOUN',
#  'walk|VERB',
#  'mostly|ADV',
#  'foreign|ADJ',
#  'democracy|NOUN',
#  'mind|VERB',
#  'r|VERB',
#  'might|VERB',
#  'later|ADV',
#  'within|ADP',
#  'times|NOUN',
#  'look|NOUN',
#  'hacked|VERB',
#  'shadow|NOUN',
#  'dead|ADJ',
#  'fight|VERB',
#  'fuck|NOUN',
#  'spencer|NOUN',
#  'wikileaks|VERB',
#  'in|PART',
#  'coincidence|NOUN',
#  'records|NOUN',
#  'hire|VERB',
#  'brexit|NOUN',
#  'immediately|ADV',
#  'marine_le_pen|NOUN',
#  'guilty|ADJ',
#  'told|VERB',
#  'abortion|NOUN',
#  'society|NOUN',
#  'tried|VERB',
#  'female|ADJ',
#  'filth|NOUN',
#  'mom|NOUN',
#  'alive|ADJ',
#  'user_mention_user_mention_user_mention|NOUN',
#  'tired|ADJ',
#  'check|VERB',
#  'quote|VERB',
#  'push|VERB',
#  'gets|VERB',
#  'broken|VERB',
#  'remain|VERB',
#  'inauguration|NOUN',
#  'worry|VERB',
#  'such|ADJ',
#  'determine|VERB',
#  'everywhere|ADV',
#  's|VERB',
#  'middle|NOUN',
#  'campaign|NOUN',
#  'once|ADV',
#  'happy|ADJ',
#  'mayor|NOUN',
#  'murdered|VERB',
#  'caught|VERB',
#  "'m|VERB",
#  'vote|NOUN',
#  "'s|VERB",
#  'speech|NOUN',
#  'enemy|NOUN',
#  'follow|VERB',
#  'zero|CARDINAL',
#  '’s|NOUN',
#  'balls|NOUN',
#  'book|NOUN',
#  'extremely|ADV',
#  'nope|NOUN',
#  'i|PRON',
#  'scary|ADJ',
#  'defend|VERB',
#  'jews|NOUN',
#  'old|ADJ',
#  'syria|NOUN',
#  'line|NOUN',
#  'migrants|NOUN',
#  'space|NOUN',
#  'language|NOUN',
#  'degeneracy|NOUN',
#  'clinton|PROPN',
#  'btw|ADV',
#  'trash|NOUN',
#  'position|NOUN',
#  'europeans|NOUN',
#  'keeping|VERB',
#  'picked|VERB',
#  'else|ADV',
#  'fail|VERB',
#  'whitegenocide|NOUN',
#  'sure|ADV',
#  'away|ADV',
#  'result|NOUN',
#  'cry|VERB',
#  'oh|INTJ',
#  'along|ADV',
#  'woke|VERB',
#  'afraid|ADJ',
#  'buy|VERB',
#  'whom|NOUN',
#  'paid|VERB',
#  'patriot|NOUN',
#  'israel|ENT',
#  'put|VERB',
#  'history|NOUN',
#  'advocating|VERB',
#  'down|ADV',
#  'british|NOUN',
#  'plot|NOUN',
#  'narrative|NOUN',
#  'deport|VERB',
#  'white_privilege|NOUN',
#  'wonder|NOUN',
#  'vote|VERB',
#  'dr|PROPN',
#  'nyt|NOUN',
#  'racist|ADJ',
#  'smart|ADJ',
#  'logic|NOUN',
#  'attention|NOUN',
#  ';|PUNCT',
#  'pres|NOUN',
#  'style|NOUN',
#  'help|NOUN',
#  'is|VERB',
#  'already|ADV',
#  'join|VERB',
#  'cut|VERB',
#  'virtue|NOUN',
#  'crying|VERB',
#  'pick|VERB',
#  'become|VERB',
#  'last|ADJ',
#  'stopped|VERB',
#  'cleaning|VERB',
#  'views|NOUN',
#  'victory|NOUN',
#  'list|NOUN',
#  'own|VERB',
#  'may|VERB',
#  'without|ADP',
#  'user_mention_user_mention|NOUN',
#  'celebrate|VERB',
#  'weak|ADJ',
#  'irish|ADJ',
#  'sex|NOUN',
#  '..|PUNCT',
#  'meet|VERB',
#  'surely|ADV',
#  'home|NOUN',
#  'pushing|VERB',
#  'bad|ADJ',
#  'brought|VERB',
#  'indeed|ADV',
#  'been|VERB',
#  'bless|VERB',
#  'forget|VERB',
#  'sides|NOUN',
#  'ladies|NOUN',
#  'stop|VERB',
#  'still|ADV',
#  'based|VERB',
#  'doing|VERB',
#  'facts|NOUN',
#  'fight|NOUN',
#  'prove|VERB',
#  'le|X',
#  'hell|NOUN',
#  'well|INTJ',
#  'built|VERB',
#  'until|ADP',
#  'deep|ADJ',
#  'protest|VERB',
#  'pro|ADJ',
#  'pleased|ADJ',
#  'pathetic|ADJ',
#  'becoming|VERB',
#  'following|VERB',
#  'lately|ADV',
#  'name|NOUN',
#  ']|PUNCT',
#  'bought|VERB',
#  'nature|NOUN',
#  'blame|VERB',
#  'one|CARDINAL',
#  'attack|NOUN',
#  'cars|NOUN',
#  'like|ADP',
#  'liar|NOUN',
#  'seen|VERB',
#  'good|ADJ',
#  'post|NOUN',
#  'now|ADV',
#  'fed|VERB',
#  'fought|VERB',
#  'neither|DET',
#  'rock|NOUN',
#  'shitlibs|NOUN',
#  'father|NOUN',
#  'lol|INTJ',
#  'sell|VERB',
#  'feed|VERB',
#  'german|ADJ',
#  'each|DET',
#  'damn|ADV',
#  'feminism|NOUN',
#  'feel|VERB',
#  'speaks|VERB',
#  'european|ADJ',
#  'story|NOUN',
#  'shit|NOUN',
#  'obama|NOUN',
#  'white_genocide|NOUN',
#  'one|NUM',
#  'cool|ADJ',
#  'petition|NOUN',
#  'sounds|VERB',
#  'view|NOUN',
#  'nor|CONJ',
#  'amazing|ADJ',
#  'rise|VERB',
#  'year|NOUN',
#  'bannon|NOUN',
#  'love|VERB',
#  'come|VERB',
#  'disc|NOUN',
#  'books|NOUN',
#  'seem|VERB',
#  'absolutely|ADV',
#  'business|NOUN',
#  'user_mention|NUM',
#  'getting|VERB',
#  'signalling|VERB',
#  'fly|VERB',
#  'affirmative_action|NOUN',
#  'ur|ADP',
#  'on|PART',
#  'arrest|VERB',
#  'commie|NOUN',
#  'f|X',
#  'minority|NOUN',
#  'google|NOUN',
#  'leaders|NOUN',
#  'france|NOUN',
#  'economy|NOUN',
#  'money|NOUN',
#  'telling|VERB',
#  'cologne|NOUN',
#  'then|ADV',
#  'leader|NOUN',
#  'horror|NOUN',
#  'heritage|NOUN',
#  'reported|VERB',
#  'de|X',
#  'multiculturalism|NOUN',
#  'sometimes|ADV',
#  'treat|VERB',
#  'sand|NOUN',
#  'love|NOUN',
#  'traitors|NOUN',
#  'ass|NOUN',
#  'fair|ADJ',
#  'number|NOUN',
#  'refugee|NOUN',
#  'she|PRON',
#  'drinking|VERB',
#  'button|NOUN',
#  'form|NOUN',
#  'trump2016|X',
#  'nrx_#altright|NOUN',
#  'breitbart|NOUN',
#  'asked|VERB',
#  'lol|NOUN',
#  'disgusting|VERB',
#  ':)|PUNCT',
#  'either|ADV',
#  'same_thing|NOUN',
#  'decades|DATE',
#  '8|CARDINAL',
#  'keep|VERB',
#  '5|CARDINAL',
#  'nationalism|NOUN',
#  'safe|ADJ',
#  'country|NOUN',
#  'destruction|NOUN',
#  'vs|ADP',
#  'laws|NOUN',
#  'normal|ADJ',
#  'illegally|ADV',
#  'trouble|NOUN',
#  'failure|NOUN',
#  'laughing|VERB',
#  'care|NOUN',
#  "'s|PART",
#  'wonder|VERB',
#  'charles|NOUN',
#  'nationalist|ADJ',
#  'create|VERB',
#  'include|VERB',
#  'about|ADP',
#  'did|VERB',
#  'user_mention_user_mention_user_mention_user_mention_user_mention_user_mention|NOUN',
#  'girls|NOUN',
#  'using|VERB',
#  'europe|NOUN',
#  'ever|ADV',
#  'asians|NOUN',
#  're|ADP',
#  'at|ADV',
#  'no|DET',
#  'problems|NOUN',
#  'conversation|NOUN',
#  'blue|ADJ',
#  'talking|VERB',
#  'race|NOUN',
#  'guy|NOUN',
#  'fired|VERB',
#  'college|NOUN',
#  'nation|NOUN',
#  'back|NOUN',
#  'breaking|VERB',
#  'way|ADV',
#  'hungary|ADJ',
#  'tweets|NOUN',
#  'episode|NOUN',
#  'netherlands|NOUN',
#  'allow|VERB',
#  'hair|NOUN',
#  'loud|ADJ',
#  'white_people|NOUN',
#  'english|ADJ',
#  'communist|NOUN',
#  'beauty|NOUN',
#  'see|VERB',
#  'u|ADJ',
#  'on|ADV',
#  'thanks|NOUN',
#  'socialism|NOUN',
#  'someone|NOUN',
#  'action|NOUN',
#  'bit|NOUN',
#  'defending|VERB',
#  'supposed|VERB',
#  'wanna|ADV',
#  'brutal|ADJ',
#  't-shirt|NOUN',
#  'my|INTJ',
#  'savages|NOUN',
#  'per|ADP',
#  'christmas|NOUN',
#  'sir|NOUN',
#  '”|PUNCT',
#  'march|NOUN',
#  'these_days|DATE',
#  'whenever|ADV',
#  'u|NOUN',
#  'seems|VERB',
#  'willing|ADJ',
#  'team|NOUN',
#  'sleep|VERB',
#  'indians|NOUN',
#  'gave|VERB',
#  'possibly|ADV',
#  'price|NOUN',
#  'generation|NOUN',
#  'angry|ADJ',
#  'water|NOUN',
#  'ground|NOUN',
#  'church|NOUN',
#  'stuff|NOUN',
#  'whatever|ADJ',
#  'facebook|NOUN',
#  'surprised|ADJ',
#  'especially|ADV',
#  'rises|VERB',
#  'born|VERB',
#  'any|DET',
#  'hate|VERB',
#  'sense|NOUN',
#  'losing|VERB',
#  'explains|VERB',
#  'complete|ADJ',
#  'stole|VERB',
#  'innocent|ADJ',
#  'top|ADJ',
#  'illegal_immigrants|NOUN',
#  'test|NOUN',
#  'controlled|VERB',
#  'does|VERB',
#  'only|ADJ',
#  'drop|VERB',
#  'wins|VERB',
#  'thrown|VERB',
#  'practice|NOUN',
#  'owned|VERB',
#  'wuz|VERB',
#  'however|ADV',
#  'considered|VERB',
#  'fast|ADV',
#  'waking|VERB',
#  'morons|NOUN',
#  'lmao|NOUN',
#  'us|PRON',
#  'got|VERB',
#  'government|NOUN',
#  'photo|NOUN',
#  'christian|ADJ',
#  'likely|ADJ',
#  'feelings|NOUN',
#  'due|ADJ',
#  'long|ADV',
#  'attacking|VERB',
#  'want|VERB',
#  'almost|ADV',
#  'mean|VERB',
#  'deported|VERB',
#  'destroyed|VERB',
#  'hope|VERB',
#  'street|NOUN',
#  'every|DET',
#  'policy|NOUN',
#  'ten_years|DATE',
#  'glad|ADJ',
#  'appear|VERB',
#  'votes|NOUN',
#  'filthy|ADJ',
#  'everything|NOUN',
#  'everybody|NOUN',
#  'congrats|NOUN',
#  'interested|ADJ',
#  'maga|NOUN',
#  'dinner|NOUN',
#  'invaders|NOUN',
#  'rebel|NOUN',
#  'monday|NOUN',
#  'concept|NOUN',
#  'ya|PRON',
#  'muslim_brotherhood|NOUN',
#  'years|NOUN',
#  'company|NOUN',
#  'down|ADP',
#  'racism|NOUN',
#  'in|ADV',
#  'do|VERB',
#  'add|VERB',
#  '’s|PUNCT',
#  'example|NOUN',
#  'comparison|NOUN',
#  'yesterday|DATE',
#  'wo|VERB',
#  'answer|VERB',
#  'forward|ADV',
#  'thought|VERB',
#  'gays|NOUN',
#  'standing|VERB',
#  '&|CONJ',
#  'becomes|VERB',
#  'charlotte|NOUN',
#  'nrx|NOUN',
#  'exactly|ADV',
#  'pride|NOUN',
#  'way|NOUN',
#  'build|VERB',
#  'blog|NOUN',
#  'cares|VERB',
#  'ideology|NOUN',
#  'up|ADV',
#  'realized|VERB',
#  'parents|NOUN',
#  'among|ADP',
#  'mr|PRON',
#  'trying|VERB',
#  'putting|VERB',
#  'w|ADP',
#  '100%|PERCENT',
#  'all|ADV',
#  'her|ADJ',
#  'wages|NOUN',
#  'burn|VERB',
#  'than|ADP',
#  'uh|INTJ',
#  'wearing|VERB',
#  'horrible|ADJ',
#  'posterity|NOUN',
#  'light|NOUN',
#  'victims|NOUN',
#  '=|PUNCT',
#  '"|PUNCT',
#  'totally|ADV',
#  'bro|NOUN',
#  'cat|NOUN',
#  'what|NOUN',
#  'europe|VERB',
#  'ban|NOUN',
#  'normies|NOUN',
#  'oppose|VERB',
#  'skin|NOUN',
#  'traitor|NOUN',
#  'tells|VERB',
#  'let|VERB',
#  'genocide|NOUN',
#  'elections|NOUN',
#  'shame|NOUN',
#  'duke|NOUN',
#  'black_people|NOUN',
#  'together|ADV',
#  'jobs|NOUN',
#  'illegal|ADJ',
#  'claim|VERB',
#  'except|ADP',
#  'victim|NOUN',
#  'antifa|NOUN',
#  'holy|ADJ',
#  'terms|NOUN',
#  'would|VERB',
#  'pulls|VERB',
#  'themselves|PRON',
#  'reading|NOUN',
#  'anyway|ADV',
#  'muslim|ADJ',
#  'years|DATE',
#  'hands|NOUN',
#  'allowed|VERB',
#  '[|PUNCT',
#  'argument|NOUN',
#  'brown|ADJ',
#  'stick|VERB',
#  'blood|NOUN',
#  'double|ADJ',
#  'miss|VERB',
#  'close|VERB',
#  'war|NOUN',
#  'hearing|VERB',
#  'cia|NOUN',
#  'movie|NOUN',
#  'clearly|ADV',
#  'learn|VERB',
#  'tax|NOUN',
#  'attacks|NOUN',
#  'belongs|VERB',
#  'progress|NOUN',
#  'freedom|NOUN',
#  'research|NOUN',
#  'deportation|NOUN',
#  'piece|NOUN',
#  'soft|ADJ',
#  'something|NOUN',
#  'moslems|NOUN',
#  'donald_trump|NOUN',
#  'death|NOUN',
#  'point|NOUN',
#  'terrorists|NOUN',
#  'k|NOUN',
#  'dnc|NOUN',
#  'please|INTJ',
#  'white_countries|NOUN',
#  'moron|NOUN',
#  'back|PART',
#  'islamic|ADJ',
#  'playing|VERB',
#  'pass|VERB',
#  'false|ADJ',
#  'needs|VERB',
#  'excellent|ADJ',
#  'out|PART',
#  'actions|NOUN',
#  'will|VERB',
#  'forum|NOUN',
#  'unless|ADP',
#  'low|ADJ',
#  'choice|NOUN',
#  'bc|ADP',
#  'fun|NOUN',
#  'gone|VERB',
#  'u.s|NOUN',
#  'shocking|ADJ',
#  'man|NOUN',
#  'president|NOUN',
#  'knew|VERB',
#  'cities|NOUN',
#  'natural|ADJ',
#  'corrupt|ADJ',
#  'wife|NOUN',
#  'saying|VERB',
#  'idea|NOUN',
#  '’s|PROPN',
#  'cross|NOUN',
#  'u|PROPN',
#  'finally|ADV',
#  'political|ADJ',
#  'around|PART',
#  'right|INTJ',
#  'comment|NOUN',
#  'lie|NOUN',
#  'white_man|NOUN',
#  'living|VERB',
#  'groups|NOUN',
#  'wing|NOUN',
#  'thing|NOUN',
#  '❤|NOUN',
#  'has|VERB',
#  'look|VERB',
#  'as|ADV',
#  'banned|VERB',
#  'replace|VERB',
#  'tolerance|NOUN',
#  'planet|NOUN',
#  'making|VERB',
#  'mother|NOUN',
#  'better|ADV',
#  'much|ADV',
#  'diversity|NOUN',
#  'mouth|NOUN',
#  'cpac|NOUN',
#  'british|ADJ',
#  'africa|NOUN',
#  'all|DET',
#  '||ADJ',
#  'user_mention_user_mention_trump|NOUN',
#  'clinton|VERB',
#  'need|NOUN',
#  'happen|VERB',
#  'consequences|NOUN',
#  'instead|ADV',
#  'terrible|ADJ',
#  'blow|VERB',
#  'literally|ADV',
#  'le_pen|NOUN',
#  'next|ADV',
#  'elected|VERB',
#  'needed|VERB',
#  'from|ADP',
#  'deep_state|NOUN',
#  'source|NOUN',
#  'fall|VERB',
#  'muh|NOUN',
#  'that|ADV',
#  'king|NOUN',
#  'even|ADV',
#  'hitler|NOUN',
#  'use|VERB',
#  'destroying|VERB',
#  'kicked|VERB',
#  'quit|VERB',
#  'very|ADV',
#  'bridge|NOUN',
#  'plenty|NOUN',
#  'moving|VERB',
#  '2016|DATE',
#  'kids|NOUN',
#  'hilarious|ADJ',
#  'at|ADP',
#  'guys|NOUN',
#  'dies|VERB',
#  'libs|NOUN',
#  'future|NOUN',
#  'ad|NOUN',
#  'around|ADP',
#  'assaulted|VERB',
#  'germany|NOUN',
#  'student|NOUN',
#  'power|NOUN',
#  'hail|NOUN',
#  'watched|VERB',
#  'most|ADV',
#  'most_people|NOUN',
#  'for|ADP',
#  'two|CARDINAL',
#  'focus|VERB',
#  'that|ADJ',
#  'damn|NOUN',
#  'gotta|NOUN',
#  'used|VERB',
#  'benghazi|NOUN',
#  'children|NOUN',
#  'dad|NOUN',
#  'u|PUNCT',
#  'these|DET',
#  'ahead|ADV',
#  'learned|VERB',
#  'please|VERB',
#  'song|NOUN',
#  'fraud|NOUN',
#  '!|PUNCT',
#  'anymore|ADV',
#  'nt|ADV',
#  'okay|ADJ',
#  '1|CARDINAL',
#  'ah|INTJ',
#  'kid|NOUN',
#  'tomorrow|DATE',
#  'point|VERB',
#  'face|NOUN',
#  'reaction|NOUN',
#  'press|NOUN',
#  'sign|NOUN',
#  'science|NOUN',
#  '–|PUNCT',
#  'asking|VERB',
#  '4|NUM',
#  'hot|ADJ',
#  'states|NOUN',
#  'around|ADV',
#  'commies|NOUN',
#  'soon|ADV',
#  'great|ADJ',
#  'takes|VERB',
#  'take|VERB',
#  'lose|VERB',
#  'investigate|VERB',
#  'done|VERB',
#  'sound|VERB',
#  'tcot_#nrx_#altright|NOUN',
#  'benefits|NOUN',
#  'border|NOUN',
#  'save|VERB',
#  'apart|ADV',
#  'ones|NOUN',
#  'comes|VERB',
#  'top|NOUN',
#  'my|ADJ',
#  '10|CARDINAL',
#  'bs|NOUN',
#  'nobody|NOUN',
#  'under|ADP',
#  'ryan|NOUN',
#  'return|VERB',
#  'other|ADJ',
#  'found|VERB',
#  'right|ADV',
#  'call|NOUN',
#  'they|PRON',
#  '#|PUNCT',
#  'ugly|ADJ',
#  'drive|VERB',
#  'order|NOUN',
#  'situation|NOUN',
#  'yeah|INTJ',
#  'self|NOUN',
#  'claims|NOUN',
#  'general|ADJ',
#  'beaten|VERB',
#  'destroy|VERB',
#  'b/c|ADP',
#  'being|VERB',
#  'wondering|VERB',
#  'exposed|VERB',
#  'rule|NOUN',
#  'funded|VERB',
#  'mexico|NOUN',
#  'communities|NOUN',
#  'trump|VERB',
#  'suppose|VERB',
#  'heart|NOUN',
#  'yet|CONJ',
#  'religion|NOUN',
#  'saw|VERB',
#  'support|VERB',
#  'canada|NOUN',
#  'eat|VERB',
#  'looked|VERB',
#  'first|ORDINAL',
#  'added|VERB',
#  'ears|NOUN',
#  'according|VERB',
#  'exactly_what|NOUN',
#  'hillary|NOUN',
#  'lady|NOUN',
#  'cause|NOUN',
#  'sign|VERB',
#  'names|NOUN',
#  'twitter|NOUN',
#  'close|ADV',
#  'with|ADP',
#  'etc|X',
#  'over|ADV',
#  'makes|VERB',
#  'terrorist|ADJ',
#  'culture|NOUN',
#  'edited|VERB',
#  'honor|NOUN',
#  'muslims|NOUN',
#  'pull|VERB',
#  'home|ADV',
#  'west|NOUN',
#  'on|ADP',
#  'best|ADJ',
#  'kills|VERB',
#  'course|NOUN',
#  "'ve|VERB",
#  'followed|VERB',
#  'sitting|VERB',
#  'land|NOUN',
#  'black|ADJ',
#  'full|ADJ',
#  'boss|NOUN',
#  'failed|VERB',
#  'toward|ADP',
#  '/|SYM',
#  'adolf|NOUN',
#  'people|NOUN',
#  'mr|INTJ',
#  'white_women|NOUN',
#  'nothing|NOUN',
#  'and|CONJ',
#  'whites|NOUN',
#  'never|ADV',
#  'refugees|NOUN',
#  'noticed|VERB',
#  'interview|NOUN',
#  'rapefugees|NOUN',
#  'five|CARDINAL',
#  'england|NOUN',
#  ')|PUNCT',
#  'protests|NOUN',
#  'enjoy|VERB',
#  'think|VERB',
#  'minorities|NOUN',
#  'thinks|VERB',
#  'easily|ADV',
#  'political_correctness|NOUN',
#  'single|ADJ',
#  'duty|NOUN',
#  'loyalty|NOUN',
#  'came|VERB',
#  'butt|NOUN',
#  'women|NOUN',
#  '#|PART',
#  'final|ADJ',
#  'bleed|VERB',
#  'hopefully|ADV',
#  'so|ADP',
#  'rt|NOUN',
#  'response|NOUN',
#  'entirely|ADV',
#  'louisiana|NOUN',
#  'arrested|VERB',
#  'here|ADV',
#  'message|NOUN',
#  'behave|VERB',
#  'game|NOUN',
#  'court|NOUN',
#  'sick|ADJ',
#  'article|NOUN',
#  'threat|NOUN',
#  'holocaust|NOUN',
#  '=|SYM',
#  'accountable|ADJ',
#  'men|NOUN',
#  'leftist|ADJ',
#  'end|VERB',
#  'real|ADJ',
#  'democrats|ENT',
#  'george|NOUN',
#  'spread|VERB',
#  'christians|NOUN',
#  'broke|VERB',
#  'felt|VERB',
#  'could|VERB',
#  'peter|VERB',
#  'dude|NOUN',
#  '(|PUNCT',
#  'our|ADJ',
#  'education|NOUN',
#  'hardly|ADV',
#  'quickly|ADV',
#  'created|VERB',
#  'dangerous|ADJ',
#  'color|NOUN',
#  'risk|NOUN',
#  'if|ADP',
#  'choose|VERB',
#  'holding|VERB',
#  'more|ADJ',
#  'capable|ADJ',
#  'fact|NOUN',
#  'ireland|NOUN',
#  'opinion|NOUN',
#  'comments|NOUN',
#  'tweet|NOUN',
#  '’s|VERB',
#  'need|VERB',
#  'struggled|VERB',
#  'percentage|NOUN',
#  'granting|VERB',
#  'jackson|NOUN',
#  'daily_beast|NOUN',
#  'nasty|ADJ',
#  'hand|VERB',
#  'couldn’t|VERB',
#  'judging|VERB',
#  'go|NOUN',
#  'competition|NOUN',
#  'american_society|NOUN',
#  'scheduled|VERB',
#  'subjects|NOUN',
#  'indoctrination|NOUN',
#  'apes|NOUN',
#  'careful|ADJ',
#  'stronger|ADJ',
#  'polish|NOUN',
#  'mood|NOUN',
#  'occurred|VERB',
#  'theirs|PRON',
#  'republicans|NOUN',
#  'capita|NOUN',
#  'sons|NOUN',
#  'they’re|DET',
#  'obey|VERB',
#  'jack|NOUN',
#  'knowing|VERB',
#  'stars|NOUN',
#  'realised|VERB',
#  'vowed|VERB',
#  'oath|NOUN',
#  'flow|NOUN',
#  'sink|VERB',
#  'goys|NOUN',
#  'creatures|NOUN',
#  'shill|NOUN',
#  'appointed|VERB',
#  'chicago|PROPN',
#  '3|NUM',
#  'mass|ADJ',
#  'w/|ADJ',
#  'gay_marriage|NOUN',
#  'distribute|VERB',
#  'footage|NOUN',
#  'debate|VERB',
#  'republican_party|NOUN',
#  'secret|ADJ',
#  'melbourne|NOUN',
#  'key|ADJ',
#  'release|NOUN',
#  'sentence|NOUN',
#  'friendly|ADJ',
#  'suspicion|NOUN',
#  'prisons|NOUN',
#  'poc|NOUN',
#  'proudly|ADV',
#  'istanbul|NOUN',
#  'perfectly|ADV',
#  'conflicts|NOUN',
#  'suffer|VERB',
#  'isn’t|NOUN',
#  'diverse|ADJ',
#  'dominance|NOUN',
#  'break|NOUN',
#  'maintain|VERB',
#  'trolls|NOUN',
#  'dream|VERB',
#  'intention|NOUN',
#  'begging|VERB',
#  'colorado|NOUN',
#  'bored|ADJ',
#  'pot|NOUN',
#  'winter|NOUN',
#  'par|NOUN',
#  'meetings|NOUN',
#  'demographics|NOUN',
#  'great_britain|NOUN',
#  'december|NOUN',
#  'sexuality|NOUN',
#  '1992|DATE',
#  'iphone|NOUN',
#  'offensive|ADJ',
#  'immigrant|ADJ',
#  'compatible|ADJ',
#  'conclude|VERB',
#  'questioned|VERB',
#  'integrate|VERB',
#  'black_crime|NOUN',
#  'smh|NOUN',
#  'examining|VERB',
#  'investigating|VERB',
#  'admitted|VERB',
#  'don’t|PROPN',
#  'outraged|ADJ',
#  '18|NUM',
#  'little_girl|NOUN',
#  'shapiro|NOUN',
#  'massachusetts|NOUN',
#  'midst|NOUN',
#  'hid|VERB',
#  'temporarily|ADV',
#  'global_warming|NOUN',
#  'prevented|VERB',
#  'slaughter|VERB',
#  'owner|NOUN',
#  'division|NOUN',
#  'hunt|NOUN',
#  'la|DET',
#  'sit|VERB',
#  'corrupted|VERB',
#  'disappear|VERB',
#  'resulting|VERB',
#  'pedophilia|NOUN',
#  '2006|DATE',
#  'jurisdiction|NOUN',
#  'donate|VERB',
#  'rewarded|VERB',
#  'spying|VERB',
#  'marking|VERB',
#  'kiev|NOUN',
#  'cold_war|NOUN',
#  'incompetent|ADJ',
#  '90|CARDINAL',
#  'irony|NOUN',
#  'trump_administration|NOUN',
#  'criticism|NOUN',
#  'corner|NOUN',
#  'purchase|VERB',
#  'steps|NOUN',
#  'stopping|VERB',
#  '….|PUNCT',
#  'traveling|VERB',
#  'reputation|NOUN',
#  'trail|NOUN',
#  'wholly|ADV',
#  'real_clear_liberty|NOUN',
#  'judgment|NOUN',
#  'alert|NOUN',
#  'head|VERB',
#  'secure|VERB',
#  'rooted|VERB',
#  'brazil|NOUN',
#  'suit|NOUN',
#  'emphasize|VERB',
#  'carson|NOUN',
#  'customers|NOUN',
#  'participants|NOUN',
#  'manhattan|NOUN',
#  'useful|ADJ',
#  'intervened|VERB',
#  'rabbis|NOUN',
#  'threaten|VERB',
#  'sealed|VERB',
#  'escaping|VERB',
#  'settle|VERB',
#  'focuses|VERB',
#  'conducted|VERB',
#  'association|NOUN',
#  'they’d|PART',
#  'afternoon|TIME',
#  'nowadays|ADV',
#  'reasoning|NOUN',
#  'limited|VERB',
#  'across|PART',
#  'american_workers|NOUN',
#  'suspect|ADJ',
#  'b|X',
#  'daily_stormer|NOUN',
#  'america|ADJ',
#  'daily|ADJ',
#  'dared|VERB',
#  '300|CARDINAL',
#  'madonna|NOUN',
#  'panic|NOUN',
#  'lowest|ADJ',
#  'homos|NOUN',
#  'glorious|ADJ',
#  'co|NOUN',
#  'suffered|VERB',
#  'connection|NOUN',
#  'recovering|VERB',
#  'conduct|VERB',
#  'homo|NOUN',
#  'needs|NOUN',
#  'physical|ADJ',
#  'more_time|NOUN',
#  'saturday|NOUN',
#  'racial_hatred|NOUN',
#  'enlightenment|NOUN',
#  'deputies|NOUN',
#  '14|NUM',
#  'nurse|NOUN',
#  'transcript|NOUN',
#  'shock|NOUN',
#  'ukraine|NOUN',
#  'partners|NOUN',
#  'relates|VERB',
#  'myths|NOUN',
#  'dc|NOUN',
#  'challenging|VERB',
#  'mankind|NOUN',
#  'path|NOUN',
#  'games|NOUN',
#  'disaster|NOUN',
#  'anti-whites|NOUN',
#  'crossing|VERB',
#  'dealt|VERB',
#  'patton|NOUN',
#  '’s_office|NOUN',
#  'eaten|VERB',
#  'poverty|NOUN',
#  'smashed|VERB',
#  'touching|VERB',
#  '“|VERB',
#  '“|SYM',
#  'large_part|NOUN',
#  'harry|NOUN',
#  'doesn’t|PROPN',
#  'new_report|NOUN',
#  'refugee_crisis|NOUN',
#  'morning|TIME',
#  'presently|ADV',
#  'above|ADJ',
#  'alan|NOUN',
#  'tennessee|NOUN',
#  'regret|VERB',
#  'institute|NOUN',
#  '’s|ADP',
#  'chemical_weapons|NOUN',
#  'treated|VERB',
#  'black_violence|NOUN',
#  'taxpayers|NOUN',
#  'n|NOUN',
#  'same_time|NOUN',
#  'rounded|VERB',
#  'opposes|VERB',
#  '23|NUM',
#  'academia|NOUN',
#  'states|VERB',
#  'demand|NOUN',
#  'planned|VERB',
#  'gain|VERB',
#  'tel_aviv|NOUN',
#  '20%|PERCENT',
#  'herself|PRON',
#  'encouraging|VERB',
#  'employers|NOUN',
#  'institution|NOUN',
#  'march|VERB',
#  'cocaine|NOUN',
#  'prepared|ADJ',
#  'moreover|ADV',
#  'separate|VERB',
#  'refusal|NOUN',
#  'merkel|PROPN',
#  'fences|NOUN',
#  'rhetoric|NOUN',
#  'eh|INTJ',
#  'apology|NOUN',
#  'origin|NOUN',
#  'assaulting|VERB',
#  'struggle|NOUN',
#  'jerusalem|NOUN',
#  'shot|NOUN',
#  'type|NOUN',
#  'nominated|VERB',
#  'collective|ADJ',
#  'ripped|VERB',
#  'parts|NOUN',
#  'resist|VERB',
#  'reluctant|ADJ',
#  'selfish|ADJ',
#  'violates|VERB',
#  'powell|NOUN',
#  'spokesman|NOUN',
#  'situations|NOUN',
#  'grand_jury|NOUN',
#  'defeating|VERB',
#  'clark|NOUN',
#  'abuse|NOUN',
#  'perpetrator|NOUN',
#  'ny|INTJ',
#  'obtained|VERB',
#  'convention|NOUN',
#  'distributing|VERB',
#  'outrageous|ADJ',
#  'ivanka|NOUN',
#  'shouting|VERB',
#  'whore|NOUN',
#  'cheating|VERB',
#  'regrettably|ADV',
#  'dropped|VERB',
#  'shop|NOUN',
#  'employees|NOUN',
#  'resentment|NOUN',
#  'obama_administration|NOUN',
#  'trillions|NOUN',
#  'new_jersey|NOUN',
#  'marine|NOUN',
#  'doesn’t|X',
#  'free|VERB',
#  'describe|VERB',
#  'male|ADJ',
#  'eastern_ukraine|NOUN',
#  'joined|VERB',
#  'relationship|NOUN',
#  'fantasy|NOUN',
#  'reproduce|VERB',
#  'confused|ADJ',
#  'bedroom|NOUN',
#  'rabbi|NOUN',
#  'attitudes|NOUN',
#  'counting|VERB',
#  'account|VERB',
#  'imposing|VERB',
#  'arab|ADJ',
#  'thereby|ADV',
#  'burden|NOUN',
#  'existed|VERB',
#  'motivation|NOUN',
#  'ensure|VERB',
#  'processed|VERB',
#  'contrary|NOUN',
#  '32|DATE',
#  'we’re|VERB',
#  'file|NOUN',
#  'statements|NOUN',
#  'satire|NOUN',
#  'theory|NOUN',
#  'dance|NOUN',
#  'plant|NOUN',
#  'repeatedly|ADV',
#  'hispanic|ADJ',
#  'firmly|ADV',
#  'unconstitutional|ADJ',
#  'traced|VERB',
#  'played|VERB',
#  'ford|NOUN',
#  'considering|VERB',
#  'one_year|DATE',
#  'insulted|VERB',
#  'modernity|NOUN',
#  'equivalent|ADJ',
#  'simultaneously|ADV',
#  'publicly|ADV',
#  'advocacy|NOUN',
#  'damn|ADJ',
#  'buried|VERB',
#  'you’re|X',
#  'donated|VERB',
#  'sentences|NOUN',
#  'dump|VERB',
#  'denounce|VERB',
#  'species|NOUN',
#  'happiness|NOUN',
#  'authority|NOUN',
#  'proceeded|VERB',
#  'disrupt|VERB',
#  'province|NOUN',
#  'author|NOUN',
#  'expansion|NOUN',
#  'holiday|NOUN',
#  'kosher|NOUN',
#  'june|NOUN',
#  'travel_ban|NOUN',
#  'planted|VERB',
#  '16-year|ADJ',
#  'nigel_farage|NOUN',
#  'white_supremacist|NOUN',
#  'forces|NOUN',
#  'orlando|NOUN',
#  'black_guy|NOUN',
#  'tends|VERB',
#  'dictator|NOUN',
#  'accomplish|VERB',
#  'middle_east|NOUN',
#  'kerry|NOUN',
#  'shocked|VERB',
#  'wasn’t|VERB',
#  'unhappy|ADJ',
#  'hate_crimes|NOUN',
#  'joins|VERB',
#  'express|VERB',
#  'irresponsible|ADJ',
#  'gas|NOUN',
#  'operated|VERB',
#  'realise|VERB',
#  'authors|NOUN',
#  'white_europeans|NOUN',
#  'pronounced|VERB',
#  'minutes|NOUN',
#  'queens|NOUN',
#  'load|NOUN',
#  'sort|ADV',
#  'legislation|NOUN',
#  'reviewing|VERB',
#  'health|NOUN',
#  'military|ADJ',
#  'importing|VERB',
#  'production|NOUN',
#  '23|DATE',
#  'austria|PROPN',
#  'israeli_government|NOUN',
#  'comply|VERB',
#  'intelligent|ADJ',
#  'produces|VERB',
#  'likely|ADV',
#  'distance|NOUN',
#  'blacklivesmatter|NOUN',
#  'jenkins|NOUN',
#  'vile|ADJ',
#  'honored|VERB',
#  'nuclear_war|NOUN',
#  'golden|ADJ',
#  'homosexual|ADJ',
#  'disagreed|VERB',
#  'persuade|VERB',
#  'model|NOUN',
#  '”|X',
#  'consistently|ADV',
#  'steve|VERB',
#  'six_years|DATE',
#  'washington|VERB',
#  'greatness|NOUN',
#  'magazine|NOUN',
#  'developing|VERB',
#  'necessarily|ADV',
#  'lock|VERB',
#  'recent_years|DATE',
#  'match|NOUN',
#  'beltway|NOUN',
#  'three_days|DATE',
#  'first_place|NOUN',
#  'trend|NOUN',
#  'dispute|NOUN',
#  'speed|NOUN',
#  'arrogance|NOUN',
#  'other_side|NOUN',
#  'cincinnati|NOUN',
#  'biologically|ADV',
#  'separated|VERB',
#  'escorted|VERB',
#  'noted|VERB',
#  'adolf|PROPN',
#  'adapt|VERB',
#  'heck|NOUN',
#  'frame|VERB',
#  'permission|NOUN',
#  'designed|VERB',
#  'good|NOUN',
#  'enter|VERB',
#  'encouraged|VERB',
#  'complicit|ADJ',
#  'erected|VERB',
#  'females|NOUN',
#  'pierce|VERB',
#  'prominent|ADJ',
#  'advise|VERB',
#  'v|NOUN',
#  'form|VERB',
#  'incredibly|ADV',
#  'victimized|VERB',
#  'prior|ADV',
#  'interests|NOUN',
#  '20,000|CARDINAL',
#  'hrc|NOUN',
#  'one_day|DATE',
#  'assembly|NOUN',
#  'poorly|ADV',
#  'globalists|NOUN',
#  'lesson|NOUN',
#  'agencies|NOUN',
#  'b|PUNCT',
#  'proclaimed|VERB',
#  'computer|NOUN',
#  'x|PROPN',
#  'lefties|NOUN',
#  'integrated|VERB',
#  'test|VERB',
#  'suspects|NOUN',
#  'apartheid|NOUN',
#  'cameron|NOUN',
#  'pakistan|NOUN',
#  'lines|NOUN',
#  'sacred|ADJ',
#  'alexander|NOUN',
#  'touch|VERB',
#  'missouri|NOUN',
#  'tactics|NOUN',
#  'engaging|VERB',
#  'imported|VERB',
#  'field|NOUN',
#  'leaves|VERB',
#  'excluding|VERB',
#  'funding|NOUN',
#  'collapsed|VERB',
#  'cruelty|NOUN',
#  'heavy|ADJ',
#  'boycott|NOUN',
#  'faggot|NOUN',
#  'best_way|NOUN',
#  'capital|NOUN',
#  'lead|NOUN',
#  'darren|PROPN',
#  'universe|NOUN',
#  'respond|VERB',
#  'pensions|NOUN',
#  'overwhelming_majority|NOUN',
#  'changes|NOUN',
#  'introduce|VERB',
#  'unite|VERB',
#  'teenagers|NOUN',
#  'i’ve|PUNCT',
#  'operating|VERB',
#  'warns|VERB',
#  'bnp|NOUN',
#  'newspaper|NOUN',
#  'trial|NOUN',
#  'count|VERB',
#  'confirm|VERB',
#  'flee|VERB',
#  'globalism|NOUN',
#  'i’m|ADV',
#  'reply|NOUN',
#  '1998|DATE',
#  'this_week|DATE',
#  'conversely|ADV',
#  'non-jews|NOUN',
#  'gentile|NOUN',
#  'social_security|NOUN',
#  'writing|NOUN',
#  'district|NOUN',
#  'scattered|VERB',
#  '2003|DATE',
#  'bail|NOUN',
#  '1924|DATE',
#  'migration|NOUN',
#  'tape|NOUN',
#  'last|ADV',
#  'other_nations|NOUN',
#  'monsters|NOUN',
#  'hanging|VERB',
#  'like|ADJ',
#  'invited|VERB',
#  'quote|NOUN',
#  'tossed|VERB',
#  'waged|VERB',
#  'motion|NOUN',
#  'sworn|VERB',
#  'cycle|NOUN',
#  'favored|VERB',
#  'further|ADV',
#  'thieves|NOUN',
#  'obsessed|VERB',
#  'they’ve|PRON',
#  'papers|NOUN',
#  'eventually|ADV',
#  'donald|VERB',
#  'collectively|ADV',
#  'primaries|NOUN',
#  'collapsing|VERB',
#  'economically|ADV',
#  'la|ADJ',
#  '25|DATE',
#  'atlantic|ADJ',
#  'b|NOUN',
#  'authorities|NOUN',
#  '’s|CONJ',
#  'displayed|VERB',
#  'commentary|NOUN',
#  'treating|VERB',
#  'suggestion|NOUN',
#  'soviet_union|NOUN',
#  'whining|NOUN',
#  'past|ADP',
#  'trust|NOUN',
#  'wide|ADJ',
#  'whose|ADJ',
#  'arrests|NOUN',
#  'access|NOUN',
#  '’s_population|NOUN',
#  'isn’t|PRON',
#  'presented|VERB',
#  'criminality|NOUN',
#  'laugh|NOUN',
#  'the_year|DATE',
#  'balance|NOUN',
#  'accepting|VERB',
#  'machines|NOUN',
#  'absolute|ADJ',
#  'berkeley|NOUN',
#  'providing|VERB',
#  'fellow|ADJ',
#  'bother|VERB',
#  'indicate|VERB',
#  'breeding|VERB',
#  'crashed|VERB',
#  'passed|VERB',
#  'exchange|NOUN',
#  'fixed|VERB',
#  'preaching|VERB',
#  'mass_murder|NOUN',
#  'new_orleans|NOUN',
#  'bullets|NOUN',
#  'organizers|NOUN',
#  'purely|ADV',
#  'jewish_problem|NOUN',
#  'famous|ADJ',
#  'wanna|VERB',
#  'fascinating|ADJ',
#  'shows|NOUN',
#  'share|NOUN',
#  'potential|NOUN',
#  'punch|NOUN',
#  'patriarchy|NOUN',
#  'ending|VERB',
#  'chosen|VERB',
#  'links|NOUN',
#  'users|NOUN',
#  'non|ADJ',
#  'executive_order|NOUN',
#  'big_deal|NOUN',
#  'thrive|VERB',
#  'siding|VERB',
#  'parliament|NOUN',
#  'weeks|NOUN',
#  'socialist|ADJ',
#  'launching|VERB',
#  'accordance|NOUN',
#  'cited|VERB',
#  'activists|NOUN',
#  'strive|VERB',
#  'human_being|NOUN',
#  'supervised|VERB',
#  'breach|NOUN',
#  'daily_basis|NOUN',
#  'cheer|VERB',
#  'you’ll|PRON',
#  'awful|ADJ',
#  'email|NOUN',
#  'alliance|NOUN',
#  'organisation|NOUN',
#  'leading|VERB',
#  'e.g.|ADV',
#  'jobbik|NOUN',
#  'system|NOUN',
#  'audience|NOUN',
#  'spare|VERB',
#  'familiar|ADJ',
#  'breakdown|NOUN',
#  'hello|INTJ',
#  'jerusalem_post|NOUN',
#  'advocates|NOUN',
#  'politico|NOUN',
#  'he’d|X',
#  'whole_lot|NOUN',
#  'first_time|NOUN',
#  'photographs|NOUN',
#  'foreign_policy|NOUN',
#  'politicians|NOUN',
#  'young_men|NOUN',
#  'millions|NOUN',
#  'spoken|VERB',
#  'toss|VERB',
#  'tolerant|ADJ',
#  '600|CARDINAL',
#  'confrontation|NOUN',
#  'implement|VERB',
#  'remarks|NOUN',
#  'hotel|NOUN',
#  'hedge|NOUN',
#  'aren’t|X',
#  'oven|NOUN',
#  'islamic_state|NOUN',
#  'trolled|VERB',
#  'summary|NOUN',
#  'offended|VERB',
#  'cruz|NOUN',
#  'sacrificed|VERB',
#  'screen|NOUN',
#  'succeed|VERB',
#  'hordes|NOUN',
#  'process|VERB',
#  'sucking|VERB',
#  'influx|NOUN',
#  'euros|NOUN',
#  'drawn|VERB',
#  'goodbye|NOUN',
#  'scandal|NOUN',
#  'wish|NOUN',
#  'suggested|VERB',
#  'nonsensical|ADJ',
#  'reserved|VERB',
#  'fathers|NOUN',
#  '%%URL|X',
#  'provides|VERB',
#  'relatively|ADV',
#  'suing|VERB',
#  'consciously|ADV',
#  'memories|NOUN',
#  'ape|NOUN',
#  'purposefully|ADV',
#  'attempted_murder|NOUN',
#  'fortune|NOUN',
#  'qualify|VERB',
#  'checked|VERB',
#  'shape|NOUN',
#  'reverse|VERB',
#  'noticing|VERB',
#  'utah|NOUN',
#  'score|NOUN',
#  'sunday|PROPN',
#  'exclusive|ADJ',
#  'curb|VERB',
#  'bank|NOUN',
#  'tradition|NOUN',
#  'biased|ADJ',
#  'voting|VERB',
#  'blaming|VERB',
#  'tranny|NOUN',
#  'merchant|NOUN',
#  'sympathy|NOUN',
#  'responses|NOUN',
#  'hater|NOUN',
#  'exclude|VERB',
#  'canadian|ADJ',
#  'com|NOUN',
#  'you’re|INTJ',
#  'mccain|NOUN',
#  'naming|VERB',
#  'shouted|VERB',
#  'globalization|NOUN',
#  'sexually|ADV',
#  'bird|NOUN',
#  'focus|NOUN',
#  'leaning|VERB',
#  'regularly|ADV',
#  'despise|VERB',
#  'distinction|NOUN',
#  'cosby|NOUN',
#  'louis|ADJ',
#  'up|NOUN',
#  'resort|VERB',
#  'june|ADJ',
#  'thomas|NOUN',
#  'large_number|NOUN',
#  'suv|NOUN',
#  'switzerland|NOUN',
#  'exception|NOUN',
#  'hispanics|NOUN',
#  'last_night|TIME',
#  'secret|NOUN',
#  'permanently|ADV',
#  'motivated|VERB',
#  'scam|NOUN',
#  'represents|VERB',
#  'chains|NOUN',
#  'alerted|VERB',
#  'denounced|VERB',
#  'claims|VERB',
#  'electing|VERB',
#  '47|CARDINAL',
#  'divided|VERB',
#  'appearing|VERB',
#  'bottles|NOUN',
#  'persecuted|VERB',
#  'fits|VERB',
#  '1995|DATE',
#  '’s|SYM',
#  'jerry|NOUN',
#  'planned_parenthood|NOUN',
#  'european_union|NOUN',
#  'future|ADJ',
#  '24_hours|TIME',
#  'j|PROPN',
#  'flight|NOUN',
#  'charleston|NOUN',
#  'hint|NOUN',
#  'resolve|VERB',
#  'ruling|VERB',
#  '”|PART',
#  'casualties|NOUN',
#  'height|NOUN',
#  'leaked|VERB',
#  'profile|NOUN',
#  'bully|VERB',
#  'storm|NOUN',
#  'heading|VERB',
#  'the_days|DATE',
#  '2012|DATE',
#  'challenges|NOUN',
#  'recall|VERB',
#  'reasons|NOUN',
#  'friday|PROPN',
#  'goods|NOUN',
#  'round|NOUN',
#  'celebrated|VERB',
#  'explode|VERB',
#  'liberal|NOUN',
#  'knight|NOUN',
#  'differently|ADV',
#  'afp|NOUN',
#  'scenes|NOUN',
#  'hypocrites|NOUN',
#  'pastor|NOUN',
#  'league|NOUN',
#  'supplied|VERB',
#  'provoked|VERB',
#  'boston|NOUN',
#  'oscars|NOUN',
#  '1991|DATE',
#  'emerging|VERB',
#  '000|NUM',
#  'patrol|NOUN',
#  'sexy|ADJ',
#  'rushed|VERB',
#  'adults|NOUN',
#  'mo|NOUN',
#  'acceptance|NOUN',
#  'searching|VERB',
#  'restored|VERB',
#  'canceled|VERB',
#  '||NOUN',
#  'demonstration|NOUN',
#  'rubio|NOUN',
#  'w/|ADP',
#  '“|ADJ',
#  'disney|NOUN',
#  'praising|VERB',
#  'mcdonald|NOUN',
#  'confronted|VERB',
#  'dr|PUNCT',
#  'yours|NOUN',
#  'riot|VERB',
#  'profit|NOUN',
#  'airport|NOUN',
#  'hawaii|NOUN',
#  'jewish_question|NOUN',
#  'linking|VERB',
#  'meaning|NOUN',
#  'recent_weeks|DATE',
#  'al-qaeda|ENT',
#  'dictatorship|NOUN',
#  'insurance|NOUN',
#  'sorry|INTJ',
#  'stop|NOUN',
#  'british_government|NOUN',
#  'brown|NOUN',
#  'kicking|VERB',
#  'building|NOUN',
#  'immigrant|NOUN',
#  'nbc|PROPN',
#  'independence|NOUN',
#  'foreigners|NOUN',
#  'acts|NOUN',
#  'they’re|NUM',
#  'abc|NOUN',
#  'broadcast|VERB',
#  'german|NOUN',
#  'troll|NOUN',
#  'nose|NOUN',
#  'bones|NOUN',
#  'singing|VERB',
#  'launched|VERB',
#  'george|VERB',
#  'usual|ADJ',
#  'code|NOUN',
#  'viciously|ADV',
#  'punishment|NOUN',
#  'forms|NOUN',
#  'dated|VERB',
#  'maryland|NOUN',
#  'weren’t|VERB',
#  'stupidity|NOUN',
#  'bullet|NOUN',
#  'only_thing|NOUN',
#  'khan|PROPN',
#  'prosecuting|VERB',
#  'interior|NOUN',
#  'ranks|NOUN',
#  'rightly|ADV',
#  'frequently|ADV',
#  'golden_dawn|NOUN',
#  'oppressing|VERB',
#  'jonathan|PROPN',
#  'dragging|VERB',
#  'zionist|ADJ',
#  'lit|VERB',
#  'beneficial|ADJ',
#  'clever|ADJ',
#  'apprehended|VERB',
#  'ain’t|VERB',
#  'little_girls|NOUN',
#  'mainstream_media|NOUN',
#  'spin|VERB',
#  'liberalism|NOUN',
#  'commons|NOUN',
#  'design|NOUN',
#  'cuck|VERB',
#  'witnesses|NOUN',
#  'see|INTJ',
#  'realities|NOUN',
#  'jewish_communities|NOUN',
#  'lawrence|NOUN',
#  'types|NOUN',
#  'liars|NOUN',
#  'the_weekend|DATE',
#  'don’t|PART',
#  'democratic_party|NOUN',
#  '1999|DATE',
#  'building|VERB',
#  'st|PROPN',
#  'a_few_days|DATE',
#  'race_relations|NOUN',
#  'max|NOUN',
#  'forbid|VERB',
#  'democratic|ADJ',
#  'solved|VERB',
#  'backlash|NOUN',
#  'rome|NOUN',
#  'next_week|DATE',
#  'numerous|ADJ',
#  'screwed|VERB',
#  'mystery|NOUN',
#  'unacceptable|ADJ',
#  'sexual_abuse|NOUN',
#  'viewed|VERB',
#  'launch|VERB',
#  'likes|NOUN',
#  'labelled|VERB',
#  'islam|PROPN',
#  'explained|VERB',
#  'abused|VERB',
#  'strike|VERB',
#  'explaining|VERB',
#  'owes|VERB',
#  'ankara|NOUN',
#  'pursuit|NOUN',
#  'condemned|VERB',
#  'expensive|ADJ',
#  'snowden|NOUN',
#  'pics|NOUN',
#  'appreciated|VERB',
#  'of|ADV',
#  'safer|ADJ',
#  'kike|NOUN',
#  '2020|DATE',
#  'ruining|VERB',
#  'determination|NOUN',
#  'holland|NOUN',
#  'abuse|VERB',
#  'telegraph|NOUN',
#  'refusing|VERB',
#  'chicken|NOUN',
#  'globally|ADV',
#  'imply|VERB',
#  'strategy|NOUN',
#  'rounds|NOUN',
#  'insult|NOUN',
#  'captured|VERB',
#  'title|NOUN',
#  'torah|NOUN',
#  'emotion|NOUN',
#  '29|CARDINAL',
#  'active|ADJ',
#  '£|PROPN',
#  'warfare|NOUN',
#  'porn|NOUN',
#  'carter|NOUN',
#  'marrying|VERB',
#  'monkey|NOUN',
#  'pc|NOUN',
#  'acted|VERB',
#  'labeled|VERB',
#  'finance|NOUN',
#  'grasp|VERB',
#  'york|NOUN',
#  'third|ORDINAL',
#  'quiet|ADJ',
#  'carries|VERB',
#  'follow|NOUN',
#  'waters|NOUN',
#  'gop|ADJ',
#  'existence|NOUN',
#  'earn|VERB',
#  'points|VERB',
#  'tendency|NOUN',
#  'directing|VERB',
#  'mandate|NOUN',
#  'refuses|VERB',
#  'laughter|NOUN',
#  'black_students|NOUN',
#  'uk|INTJ',
#  'cruel|ADJ',
#  'gods|NOUN',
#  'counted|VERB',
#  'bar|NOUN',
#  'trannies|NOUN',
#  'housed|VERB',
#  '2018|DATE',
#  'inspired|VERB',
#  'walls|NOUN',
#  'asserting|VERB',
#  'shifted|VERB',
# ...
#  'wives',
#  'grandfather',
#  '!!!!',
#  'aka',
#  'acting',
#  'golden',
#  'embassy',
#  'hurting',
#  'protect',
#  'compensation',
#  'rep',
#  'laws',
#  'colleagues',
#  'bacon',
#  'assailants',
#  'wounds',
#  'are',
#  'bull',
#  'brain',
#  'retribution',
#  'blind',
#  'following',
#  'trouble',
#  'travelled',
#  '#whitegenocide',
#  'bright',
#  'olympic',
#  'fair',
#  'mama',
#  'dilemma',
#  'malcolm',
#  'wondered',
#  'wave',
#  'shooter',
#  'kurt',
#  'letter',
#  'interpreted',
#  'stress',
#  'proof',
#  'brains',
#  'fiction',
#  'believes',
#  'one’s',
#  'voluntary',
#  'barry',
#  'miami',
#  'might',
#  'basic',
#  'print',
#  'wood',
#  'coastal',
#  'supporter',
#  'fellow',
#  'heated',
#  'garrison',
#  'dont',
#  'jack',
#  'class',
#  'nukes',
#  'combating',
#  'accidentally',
#  'expect',
#  'her',
#  '99%',
#  'derbyshire',
#  'eh',
#  'mississippi',
#  'wife’s',
#  'taylor',
#  'possession',
#  'confrontation',
#  'tolerant',
#  'gotten',
#  '#trumptrain',
#  'framed',
#  'personal',
#  'entirety',
#  'accommodation',
#  'retirement',
#  'purchase',
#  'hostage',
#  'ho',
#  'entertainment',
#  'construct',
#  'suffering',
#  'square',
#  'christ',
#  '😂😂😂',
#  'consciousness',
#  'outlawed',
#  'utopian',
#  '/',
#  'clergy',
#  'personalities',
#  'ballot',
#  'makes',
#  'waves',
#  'istanbul',
#  'silenced',
#  'bob',
#  'did',
#  'alfred',
#  'requirements',
#  'abu',
#  'extortion',
#  'courses',
#  'hungarian',
#  'formation',
#  'tourists',
#  ']:',
#  'digging',
#  'jq',
#  'posted',
#  'fags',
#  'articles',
#  'profile',
#  'attributed',
#  'enthusiastic',
#  'grievance',
#  'giant',
#  'toy',
#  'defenders',
#  'subhuman',
#  'inmates',
#  'given',
#  'ceremony',
#  'development',
#  'incentive',
#  'road',
#  'supposed',
#  'bullets',
#  'partisan',
#  'perry',
#  'barack',
#  'hilarious',
#  'both',
#  '1',
#  'extended',
#  'keys',
#  'matthew',
#  'anti-israel',
#  'jeremy',
#  'pronounced',
#  'holes',
#  'famous',
#  "they'd",
#  'i',
#  'stage',
#  'kill',
#  'foreigners',
#  'matters',
#  'jonathan',
#  'freed',
#  'hopefully',
#  'news',
#  '#sexed',
#  'isil',
#  'lay',
#  'suppose',
#  'divide',
#  'jones',
#  'relationship',
#  'contractors',
#  'woes',
#  'asserted',
#  '#1',
#  'gop',
#  'tribalism',
#  'la',
#  'qatar',
#  'empathy',
#  'no',
#  'active',
#  'emphasized',
#  '26-year-old',
#  'hebrew',
#  'existential',
#  'israelis',
#  'ball',
#  'ring',
#  'gay',
#  'santa',
#  'mocking',
#  'visit',
#  'slovenia',
#  'dysfunction',
#  'tbh',
#  'freely',
#  'right',
#  'sooner',
#  'exchanged',
#  'ann',
#  'estonia',
#  'shoes',
#  'closure',
#  'soros',
#  'sudanese',
#  'sexist',
#  'fabric',
#  'native',
#  'hold',
#  'democrats',
#  'faced',
#  'you’ll',
#  'deliberate',
#  'translate',
#  'functioning',
#  'colorful',
#  'depicted',
#  'opening',
#  'grabbed',
#  'dumb',
#  'homogeneous',
#  'jerusalem',
#  '2004',
#  'circle',
#  'squad',
#  'announcement',
#  'cotton',
#  'thanks',
#  'mission',
#  'instincts',
#  'birds',
#  'negotiations',
#  'facto',
#  'expressing',
#  'klux',
#  'exist',
#  'iranians',
#  'there',
#  'previous',
#  'professors',
#  'film',
#  'valued',
#  'prepared',
#  'environmental',
#  'yale',
#  'typically',
#  'ol',
#  '#dirtyjews',
#  'cuck',
#  'hungarians',
#  'hahaha',
#  'understood',
#  'romanians',
#  'let',
#  'transcript',
#  'sound',
#  'detroit',
#  'removing',
#  'ficki',
#  'japanese',
#  'dan',
#  'situation',
#  'cause',
#  'waste',
#  'qualify',
#  'ave',
#  'punches',
#  'judaism',
#  'urge',
#  'insisted',
#  'entities',
#  'nsa',
#  'colored',
#  'casualties',
#  'allegations',
#  'illegals',
#  '?!',
#  'exercise',
#  'precedent',
#  'congratulations',
#  'modernity',
#  'nazis',
#  'disclosed',
#  'rolls',
#  'denounced',
#  'settlers',
#  'october',
#  'leaking',
#  'anyway',
#  'scholarship',
#  '1967',
#  'resistance',
#  '1964',
#  'porn',
#  'kampf',
#  'xenophobia',
#  'everyone’s',
#  'family’s',
#  'silencing',
#  'wanna',
#  'speakers',
#  'threats',
#  'heard',
#  'richest',
#  'desperation',
#  'planted',
#  'avoided',
#  'feminism',
#  'hopes',
#  'deployment',
#  'individualism',
#  'takeover',
#  'anthem',
#  'serial',
#  'misunderstanding',
#  'pew',
#  'feminists',
#  'range',
#  'travelling',
#  'satellite',
#  'proposing',
#  'unidentified',
#  'universities',
#  'transformation',
#  'dumping',
#  'admissions',
#  'acceptance',
#  'fn',
#  'left',
#  '16-year-old',
#  'jail',
#  'thy',
#  'study',
#  'haley',
#  'demonstrates',
#  'ratio',
#  'kelly',
#  'lawyers',
#  'ron',
#  'criticized',
#  'disrespectful',
#  'assad’s',
#  'behaviors',
#  'ryan’s',
#  'kellyanne',
#  'dancing',
#  'hire',
#  'organizer',
#  'slammed',
#  'guests',
#  'global',
#  'millennial',
#  'divided',
#  'basket',
#  'additional',
#  'displaced',
#  'term',
#  'bolshevism',
#  'nailed',
#  'shoulder',
#  'biased',
#  'transport',
#  'rock',
#  'empowered',
#  'bribery',
#  'mocked',
#  'unsustainable',
#  'bite',
#  'nj',
#  'prefers',
#  'addressed',
#  'philippines',
#  'patrol',
#  'beating',
#  'devoted',
#  'afterward',
#  'shared',
#  'stanley',
#  'legislation',
#  'supporters',
#  'sticking',
#  'listen',
#  'majority',
#  'inferior',
#  'growth',
#  'forbidden',
#  'anthropology',
#  'guardian',
#  'grandparents',
#  'thinking',
#  'barrier',
#  'held',
#  'worlders',
#  'menace',
#  '84',
#  'savages',
#  'wilson’s',
#  'lasted',
#  'moreover',
#  'vague',
#  'blah',
#  'trading',
#  'gallery',
#  'a',
#  'street',
#  'cubans',
#  'duck',
#  'bags',
#  'confident',
#  'courts',
#  'doors',
#  'hv',
#  '23-year-old',
#  'knife',
#  'killed',
#  'dean',
#  'organisations',
#  'comedy',
#  'rules',
#  'lessons',
#  'pass',
#  'technique',
#  'wore',
#  'airline',
#  'austrian',
#  'gypsy',
#  'anti-trump',
#  'zog',
#  'possess',
#  'tactical',
#  'u.s.',
#  'meltdown',
#  'gov',
#  'holland',
#  'sector',
#  'jihad',
#  'lightly',
#  'dear',
#  'briefing',
#  'racial',
#  'rendered',
#  'rockwell',
#  'innocents',
#  'henry',
#  'betrayal',
#  'promised',
#  'navy',
#  'secret',
#  'faith',
#  'organized',
#  'residence',
#  'yours',
#  'evans',
#  'manufacturing',
#  'clueless',
#  'ended',
#  "shouldn't",
#  'reckless',
#  'outbreak',
#  'actually',
#  'beliefs',
#  'legend',
#  'bailey',
#  'empty',
#  'manslaughter',
#  'wide',
#  'discusses',
#  'vessel',
#  'increased',
#  'cnn’s',
#  'track',
#  'lovely',
#  'breathing',
#  'pouring',
#  'considering',
#  'self-determination',
#  'wins',
#  'worker',
#  'grown',
#  'richard',
#  'narrations',
#  'he',
#  'dat',
#  ';-)',
#  'subconscious',
#  'importantly',
#  'lgbt',
#  'incapable',
#  'newcomers',
#  'jersey',
#  'turner',
#  'murderers',
#  'implementing',
#  'brief',
#  'brooks',
#  'u.k.',
#  'blogs',
#  'hide',
#  'anderson',
#  'adding',
#  'parish',
#  'salute',
#  'assimilation',
#  'anti-jewish',
#  'person',
#  'islamists',
#  'rose',
#  'projects',
#  '34',
#  '1980',
#  'euro',
#  'pilot',
#  'arena',
#  '?',
#  'fringe',
#  'despair',
#  'comfort',
#  'nationwide',
#  'activist',
#  'search',
#  '1%',
#  'traditionalist',
#  'trigger',
#  'q',
#  'homosexual',
#  'hotep',
#  'escalated',
#  'distinct',
#  'pro-immigration',
#  'non-stop',
#  'train',
#  'synagogues',
#  '2010',
#  'foreign',
#  'overwhelmed',
#  'exchange',
#  'boundaries',
#  'racism',
#  'hayes',
#  'suspend',
#  'courthouse',
#  'referred',
#  'possibility',
#  'accounts',
#  'newly',
#  'jfk',
#  'coral',
#  'prosecutor',
#  'idiot',
#  '#auspol',
#  'organizations',
#  'donated',
#  'socialist',
#  'comet',
#  'hollande',
#  'unsafe',
#  'excuse',
#  'inspector',
#  'noted',
#  'patriotism',
#  'iconic',
#  'small',
#  'priority',
#  'quite',
#  'regions',
#  'senators',
#  'trips',
#  '29',
#  'soil',
#  'figures',
#  'netherlands',
#  'heavily',
#  'hear',
#  'funded',
#  'argued',
#  'teenage',
#  'childhood',
#  'estates',
#  'japan',
#  'gangster',
#  'shill',
#  'tale',
#  'gratitude',
#  'suspended',
#  'congress',
#  'hebdo',
#  'grade',
#  'probe',
#  'trained',
#  'hunting',
#  'jewelry',
#  'australia’s',
#  'misery',
#  'encouraging',
#  'it’ll',
#  'general',
#  'neutrality',
#  'barbara',
#  'shown',
#  'rumors',
#  'message',
#  "world's",
#  'observation',
#  'sen.',
#  'authentic',
#  'prefer',
#  'incidents',
#  'notions',
#  'mayor',
#  'dog',
#  'poem',
#  'denounce',
#  'alerted',
#  'english',
#  '–',
#  'limbaugh',
#  'affidavit',
#  'colonized',
#  'boost',
#  'caught',
#  'unarmed',
#  'reducing',
#  'frightened',
#  'hip',
#  'dyke',
#  'cannot',
#  'crimes',
#  'marginalized',
#  'sprinkle',
#  'slams',
#  'dismiss',
#  'must',
#  'mountain',
#  'repression',
#  'pill',
#  'pages',
#  'erected',
#  'wife',
#  'tricks',
#  'buchanan',
#  'candidacy',
#  'probably',
#  'greater',
#  'healthy',
#  'inherently',
#  'cake',
#  'mulatto',
#  'mein',
#  'republic',
#  'annual',
#  'breakfast',
#  'enterprise',
#  'thousands',
#  'fucking',
#  'cemetery',
#  'dark',
#  'silver',
#  'escaped',
#  'photos',
#  'military',
#  'arrogant',
#  'developments',
#  'jewry',
#  'blamed',
#  'gassed',
#  'superior',
#  'conway',
#  'actress',
#  'genders',
#  '8',
#  'controlling',
#  'perpetrators',
#  'official',
#  'zionism',
#  'munich',
#  'zion',
#  'cares',
#  'appearing',
#  'feared',
#  'view',
#  'spent',
#  'nhs',
#  'fault',
#  'tanks',
#  'haiti',
#  'femen',
#  'stir',
#  'session',
#  'guaranteed',
#  "who's",
#  '1994',
#  '18-year-old',
#  "aren't",
#  'tremendous',
#  'election',
#  'overwhelming',
#  'naacp',
#  'pardon',
#  'shelters',
#  'psychotic',
#  'scene',
#  'bars',
#  'warrior',
#  'above',
#  'bombings',
#  "israel's",
#  'remain',
#  'patrols',
#  'believers',
#  'integrate',
#  'caused',
#  'university’s',
#  'halt',
#  'sciences',
#  'falling',
#  'immoral',
#  'collective',
#  'lifestyle',
#  'neighboring',
#  'oregon',
#  'management',
#  'underground',
#  'packed',
#  'syrian',
#  'ward',
#  'regards',
#  'folk',
#  'releases',
#  'floor',
#  'marx',
#  'alcohol',
#  '32-year-old',
#  'disrespect',
#  'credentials',
#  'front',
#  'backgrounds',
#  'science',
#  'recruit',
#  'require',
#  'recognizing',
#  'pulled',
#  'unknown',
#  'drastic',
#  'stations',
#  '•',
#  'blow',
#  '150',
#  'militant',
#  "she'll",
#  'mothers',
#  'equivalent',
#  'terrified',
#  'stunning',
#  'kicks',
#  'denmark',
#  'reputation',
#  'engagement',
#  'owned',
#  'calais',
#  '23',
#  'swiss',
#  '#womensmarch',
#  'indication',
#  'designed',
#  'became',
#  'comment',
#  'priests',
#  'aircraft',
#  'assertion',
#  'disastrous',
#  'schools',
#  'randomly',
#  'took',
#  'coal',
#  '1988',
#  'dismissed',
#  'responsibility',
#  'penn',
#  'lady',
#  '59',
#  'fixing',
#  'after',
#  'couldn’t',
#  'education',
#  'standards',
#  'resettled',
#  'bizarre',
#  'offence',
#  'glad',
#  'acceptable',
#  'moines',
#  'anniversary',
#  'maria',
#  'reserve',
#  'meant',
#  'stolen',
#  'description',
#  'interpret',
#  'infiltrated',
#  'join',
#  '90%',
#  'notable',
#  'convince',
#  '35',
#  'bigoted',
#  'prediction',
#  'girl',
#  'make-up',
#  'somewhere',
#  'ricky',
#  'cattle',
#  'crack',
#  'slight',
#  'entertaining',
#  'highlighted',
#  'suburbs',
#  'hmmm',
#  'requiring',
#  'absurd',
#  'starting',
#  'dozen',
#  'those',
#  '36',
#  'once',
#  'departments',
#  'unbelievable',
#  '..',
#  'beat',
#  'ranking',
#  'fabricated',
#  'continually',
#  'risen',
#  'matches',
#  'equipment',
#  'focused',
#  'regime',
#  'crowd',
#  'bank',
#  'steel',
#  'involves',
#  'clever',
#  'does',
#  'do',
#  'filth',
#  'elect',
#  'schengen',
#  '10',
#  'amid',
#  'online',
#  'bits',
#  'towards',
#  'rings',
#  'topic',
#  'handle',
#  'nigeria',
#  'legalize',
#  'contrary',
#  'rhetorical',
#  'merely',
#  'saints',
#  'tougher',
#  'earlier',
#  'framework',
#  'country',
#  'primaries',
#  'sad',
#  'belt',
#  'exciting',
#  'brings',
#  'abraham',
#  'foolish',
#  'probation',
#  'stone',
#  'twenty',
#  'stronger',
#  'evils',
#  'methods',
#  'fat',
#  'rogue',
#  'gunned',
#  'wiesenthal',
#  'fliers',
#  'arrived',
#  'cells',
#  'constantly',
#  'invasion',
#  'neo-nazi',
#  'patriotic',
#  'destruction',
#  'closet',
#  'delivering',
#  'ww2',
#  'arts',
#  'studies',
#  'ray',
#  'affect',
#  'robbery',
#  '400',
#  'temple',
#  'cars',
#  'doj',
#  'pursue',
#  'agree',
#  'figured',
#  'remembrance',
#  'toxic',
#  'something',
#  'but',
#  'home',
#  'collapse',
#  'territories',
#  'generals',
#  'tent',
#  'hitler',
#  'confront',
#  'areas',
#  '#blacklivesmatter',
#  'see',
#  'philosophical',
#  'hammer',
#  'appointment',
#  'geneva',
#  'bullying',
#  'cooking',
#  'touched',
#  'kennedy',
#  'stuck',
#  'that',
#  'secretly',
#  'manuel',
#  'thinks',
#  'chasing',
#  'read',
#  'rocket',
#  'land',
#  'hughes',
#  'spencer',
#  'help',
#  'orientation',
#  'intentionally',
#  '80s',
#  'protecting',
#  'fucks',
#  'danish',
#  'stable',
#  'diplomats',
#  'forgotten',
#  'finds',
#  'floating',
#  'strike',
#  'kristol',
#  'tonight',
#  'recruitment',
#  'smoke',
#  'criticism',
#  'chess',
#  'mercy',
#  'breivik',
#  'assailant',
#  'cities',
#  'rhodes',
#  'forced',
#  'hysteria',
#  'pm',
#  'huh',
#  'lip',
#  'president',
#  'defends',
#  'wearing',
#  'cross',
#  'dana',
#  'bat',
#  'katie',
#  'prayers',
#  '#diversity',
#  'plays',
#  'militants',
#  '’”',
#  'amnesty',
#  'expelled',
#  'lobby',
#  'attacks',
#  'happily',
#  'athens',
#  'neighbors',
#  'ramadan',
#  'literally',
#  'uncomfortable',
#  'niggers',
#  'further',
#  'emanuel',
#  'observations',
#  'documents',
#  'sees',
#  'assault',
#  'signaling',
#  'markets',
#  'accomplices',
#  'crush',
#  'congressman',
#  'stormfront',
#  'tattoos',
#  'slogan',
#  'misguided',
#  'frontier',
#  'dropped',
#  'protesters',
#  'controlled',
#  'recipients',
#  '1960s',
#  'journalist',
#  'zombie',
#  'unusual',
#  'slowly',
#  'excitement',
#  'young',
#  'assigned',
#  'pres',
#  'devil',
#  'h',
#  'tolerate',
#  'origin',
#  'condone',
#  'games',
#  'poisonous',
#  'restaurants',
#  'leader',
#  'plain',
#  'protocol',
#  'hong',
#  'stickers',
#  'favorable',
#  "can't",
#  'accordance',
#  'pilots',
#  'tip',
#  'providing',
#  'account',
#  'sharing',
#  'adopt',
#  'background',
#  'twisted',
#  'blasio',
#  'blows',
#  'barrage',
#  'enacted',
#  'riot',
#  'seattle',
#  'joins',
#  'high',
#  'wage',
#  'scientists',
#  'influenced',
#  'anarchy',
#  'movies',
#  'sworn',
#  'disturbance',
#  'richardson',
#  'parked',
#  'replace',
#  'arriving',
#  'solely',
#  'trash',
#  '#tgdn',
#  'items',
#  'organization',
#  'change',
#  'within',
#  'libertarianism',
#  'subversive',
#  'e-mails',
#  'farmer',
#  'experienced',
#  'constituency',
#  'warning',
#  'settle',
#  'brutally',
#  'suck',
#  'outspoken',
#  'correctly',
#  'ethical',
#  "would've",
#  'judged',
#  'qc',
#  'rates',
#  'dealing',
#  'images',
#  'honorary',
#  'anyone’s',
#  'dispossession',
#  'offending',
#  'russia',
#  'hannity',
#  'horses',
#  'need',
#  'encounters',
#  'mentioned',
#  'westminster',
#  '1986',
#  'lover',
#  'server',
#  'blessing',
#  'viciously',
#  'aged',
#  'lengthy',
#  'nail',
#  'cowards',
#  'depicting',
#  'anti-white',
#  'insults',
#  'conditioned',
#  'leads',
#  'league',
#  'jason',
#  'inevitable',
#  'x',
#  'teens',
#  'conversion',
#  'reduced',
#  'candy',
#  'element',
#  'truth',
#  'skills',
#  'second',
#  'solved',
#  'detailing',
#  '#antiwhite',
#  'exclude',
#  'knight',
#  'cheating',
#  'cantor',
#  'daca',
#  'direction',
#  'victor',
#  'kikes',
#  'bishops',
#  'failing',
#  'put',
#  'postal',
#  'unto',
#  'sexuality',
#  'contest',
#  'waking',
#  'dug',
#  'pledged',
#  'halal',
#  'juan',
#  'complaints',
#  'came',
#  'failure',
#  'settlements',
#  '#muslimban',
#  'isolation',
#  'constructive',
#  'muh',
#  'alter',
#  'legacy',
#  'poop',
#  'expects',
#  'positively',
#  '3',
#  'escaping',
#  'publish',
#  'being',
#  "couldn't",
#  'leaves',
#  'destructive',
#  'alas',
#  'argue',
#  'freak',
#  'beside',
#  'socialism',
#  'flights',
#  'smarter',
#  'praying',
#  '1968',
#  'followed',
#  'talk',
#  'subsidized',
#  'incite',
#  'trillions',
#  'modest',
#  'slip',
#  'machete',
#  'derogatory',
#  'bunch',
#  'relates',
#  'viking',
#  'fined',
#  '65',
#  'surrendered',
#  'knows',
#  'throwing',
#  'widespread',
#  'registration',
#  'bone',
#  'morals',
#  'september',
#  'events',
#  'deputies',
#  'stability',
#  'courtesy',
#  'contribution',
#  'neither',
#  'applies',
#  'utterly',
#  'fl',
#  'commented',
#  'spelling',
#  'ugh',
#  'repent',
#  'hard',
#  '2nd',
#  'researchers',
#  'genes',
#  'sends',
#  'politically',
#  'conceivable',
#  'monument',
#  'necessary',
#  'politico',
#  'tries',
#  'implicitly',
#  'odds',
#  'doctrine',
#  'excluded',
#  'if',
#  'nude',
#  'didnt',
#  'seven',
#  'inaccurate',
#  'names',
#  'deported',
#  'quality',
#  'tone',
#  'grows',
#  'crossing',
#  'complex',
#  'rapper',
#  '66',
#  'reader',
#  'injuries',
#  'strategy',
#  'profoundly',
#  'boring',
#  'beloved',
#  'influences',
#  'jihadists',
#  'text',
#  'deleted',
#  'characters',
#  'caps',
#  'explore',
#  'sentence',
#  'grip',
#  'lab',
#  'enabled',
#  'amongst',
#  'row',
#  'sing',
#  'prob',
#  'italian',
#  'rarely',
#  'violation',
#  'approved',
#  'baghdad',
#  'effectively',
#  'mentality',
#  'bottles',
#  'hurt',
#  'ignores',
#  'themselves',
#  'behold',
#  'unit',
#  'smashing',
#  'choices',
#  'costly',
#  'eating',
#  'belief',
#  'tweeted',
#  'korean',
#  'overturned',
#  'pin',
#  'establishing',
#  '47',
#  'trauma',
#  'peer',
#  '?????',
#  'skrewdriver',
#  'coordinated',
#  'tech',
#  'iraqis',
#  'senior',
#  'differently',
#  'fits',
#  '😬',
#  '📷|ADJ',
#  '🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸|PUNCT',
#  'libtard|NOUN',
#  'stahl|NOUN',
#  'lone|ADJ',
#  'hotep|NOUN',
#  'shenanigans|NOUN',
#  'lone_wolf_news|NOUN',
#  '📹|ADJ',
#  'new_unfollowers|NOUN',
#  'link)related|VERB',
#  'aryan_morality|NOUN',
#  'new_tribe|NOUN',
#  'racist_singularity|NOUN',
#  'commutation|NOUN',
#  'quisling|VERB',
#  'cocaine_base|NOUN',
#  'dyer|NOUN',
#  'bho|NOUN',
#  'commuted|VERB',
#  'horowitz|PROPN',
#  'p2|X',
#  'tgdn|NOUN',
#  'ccot|NOUN',
#  'ami|PROPN',
#  'pjnet|NOUN',
#  '#refugees|NOUN',
#  '1793-1967|DATE',
#  'chagos|NOUN',
#  'chagos_islands|NOUN',
#  'user_mention_humans|NOUN',
#  'invisiblenyc|NOUN',
#  'sjolund|NOUN',
#  '174_years|DATE',
#  '£40_million|MONEY',
#  'coconut_company_plantation_era|NOUN']

# %% [markdown]
# ### Story #2
